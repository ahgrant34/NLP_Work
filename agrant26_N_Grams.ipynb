# %% [markdown]
# ## N-Grams
# #### Andrew Grant

# %% [markdown]
# ### Load Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk

# %% [markdown]
# ### Load English and Italian Datasets

# %%
# Load English df

df_en = pd.read_csv('data/CONcreTEXT_trial_EN.tsv' ,sep='\t')

# Load Italian df

df_it = pd.read_csv('data/CONcreTEXT_trial_IT.tsv' ,sep='\t')

# %%
df_en
# Out:
#          TARGET POS  INDEX                                               TEXT  \
# 0   achievement   N      3  Bring up academic achievements , awards , and ...
# 1   achievement   N      9  Please list people you have helped , your pers...
# 2      activate   V      1     Add activated carbon straight to your vodka .
# 3      activate   V     15  Place sensors around your garden , and when a ...
# 4     adventure   N      9  Look for a partner that shares your level of a...
# ..          ...  ..    ...                                                ...
# 95        water   N      5  Rinse your face with warm water and pat it dry .
# 96          win   V      4  Staying mentally strong means winning half the...
# 97          win   V      7  The person who has the highest score wins the ...
# 98        woman   N      7  For the most part , men and women wear the sam...
# 99        woman   N      3  Look at the woman whom you are listening to fo...
#
#     MEAN
# 0   3.06
# 1   3.03
# 2   3.83
# 3   5.51
# 4   2.03
# ..   ...
# 95  6.91
# 96  2.34
# 97  4.60
# 98  6.29
# 99  6.57
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Create a list of words with no punctuation and all lowercase

# %%
# Import a list of punctuations
from string import punctuation


# Function to change words to lowercase
def lower_text(text):
    #Make text lowercase 
    text = text.lower()
    return text

# function to remove punctuation
def punc_rem(text):
    text.replace("'s", "")
    return ''.join(word for word in text if word not in punctuation)

# lambda function versions for the above functions
low_clean = lambda x: lower_text(x)
punc_clean = lambda x: punc_rem(x)

# %%
# Applying the lowercase and remove punctuation functions to the English data frame
df_en_clean = pd.DataFrame(df_en['TEXT'].apply(low_clean).apply(punc_clean))

# Joining all the lines of "TEXT" in the English df into one corpus
en_clean_text = " ".join(text for text in df_en_clean['TEXT'])


# Applying the lowercase and remove punctuation functions to the Italian data frame
df_it_clean = pd.DataFrame(df_it['TEXT'].apply(low_clean).apply(punc_clean))

# Joining all the lines of "TEXT" in the Italian df into one corpus
it_clean_text = " ".join(text for text in df_it_clean['TEXT'])

# %%
# Import tokenizer
from nltk.tokenize import RegexpTokenizer

# Setting up tokenizer
tokenizer = RegexpTokenizer(r'\w+')

# Tokenizing the english corpus
en_tok_list = tokenizer.tokenize(en_clean_text)

# Tokenizing the italian corpus
it_tok_list = tokenizer.tokenize(it_clean_text)

# %% [markdown]
# ### Create Training and Test Lists

# %%
from sklearn.model_selection import train_test_split

# use the sklearn train_test_split function to randomly split the tokenized words into train and test lists
train_en, test_en = train_test_split(en_tok_list, test_size= 0.2)
train_it, test_it = train_test_split(it_tok_list, test_size= 0.2)

# %% [markdown]
# #### -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Creating the Unigram Model
#
# #### ** Please note that capitalized letters were all lowercased for the training and test sets.  This was based on the size of the training set as I didn't think there were enough words for the capatalizations to add value without also potentially throwing some unwanted bias into the models

# %%
from nltk import ngrams
from collections import Counter, defaultdict

# %%
# Function to change the list of tokenized words to a string with no blank spaces
# this is only used for the unigrams to more easily find the letter frequencies
def toString(List): 
    return ''.join(List) 

# apply to string function to the two training word lists
train_en_txt = toString(train_en)
train_it_txt = toString(train_it)

# %%
# finding the count of each letter in the string created from the training lists
en_count_sorted = Counter(train_en_txt).most_common()
it_count_sorted = Counter(train_it_txt).most_common()

# using the len function to find the total count of letters in both training lists of words
en_total_count = len(train_en_txt)    
it_total_count = len(train_it_txt)

# %%
# function that creates a list that will have a tupple made up of the letter and its frequency in the training string

def unigram_freq_counter(let_list, text):
    let_probs = []
    total_count = len(text)   
    for letter, count in let_list:
        freq = count/total_count
        let_probs.append([letter, freq])
    
    return let_probs

# %%
# apply the above function to both english and italian training list of words strings

en_prob_list = unigram_freq_counter(en_count_sorted, train_en_txt)

it_prob_list = unigram_freq_counter(it_count_sorted, train_it_txt)

# %%
# converting lists to a dictionaries so that it can be more easily read by the model function

def listtodict(A): 
    model = dict(A) 
    return model

en_model_1 = listtodict(en_prob_list)
it_model_1 = listtodict(it_prob_list)
en_model_1
# Out:
# {'e': 0.11504802561366062,
#  'o': 0.09007470651013874,
#  't': 0.08687299893276414,
#  'a': 0.08153681963713981,
#  'n': 0.07065101387406617,
#  'i': 0.06894343649946638,
#  'r': 0.06446104589114195,
#  's': 0.060832443970117396,
#  'h': 0.04525080042689435,
#  'l': 0.04503735325506937,
#  'u': 0.03457844183564568,
#  'y': 0.032017075773746,
#  'd': 0.03030949839914621,
#  'c': 0.0288153681963714,
#  'f': 0.024759871931696906,
#  'p': 0.024332977588046957,
#  'm': 0.023265741728922092,
#  'g': 0.018356456776947704,
#  'w': 0.015581643543223053,
#  'b': 0.013233724653148345,
#  'v': 0.011739594450373533,
#  'k': 0.008537886872998933,
#  'x': 0.00192102454642476,
#  'z': 0.0017075773745997866,
#  'j': 0.0010672358591248667,
#  'q': 0.0008537886872998933,
#  'é': 0.00021344717182497332}

# %%
# model to predict the language of the words in the English test list of words
    
def unigram_language_predictor(en_model,it_model, test_listofwords):
    
    # create empty results list to be appended to
    results = []
     
    # for loop that goes through all of the words in the test list of words
    for word in test_listofwords:
        
        # initially setting the probability of the word being engluish and italian to 1
        en_prob = 1
        it_prob =1
         
        # looping through the letters in each word    
        for let1 in word:
            
            # if else clause incase the letter is not a key in the dictionary from the english training list of words
            if let1 not in en_model.keys():
                en_prob = en_prob
            else:
                # model creates a probability of the word being english by multiplying the letter frequncies together
                en_prob = en_prob*en_model[let1]
            
            
            # if else clause incase the letter is not a letter key in the dictionary from the italian training list of words    
            if let1 not in it_model.keys():
                it_prob = it_prob
            else:
                # model creates a probability of the word being italian by multiplying the letter frequncies together
                it_prob = it_prob*it_model[let1]
         
        # if else statement to choose which language has a higher probability and assign that value to a variable
        if en_prob >= it_prob:
            en_flag = 1
            pred_lang= 'English'
        else:
            en_flag = 0
            pred_lang = 'Italian'
        
        # append the results to a results list created at the start of the function
        results.append([word, en_prob, it_prob, en_flag, pred_lang])
            
    return results

# %%
# run predictor using the english and italian frequency dictionaries and the english test list of words

unigram_res = unigram_language_predictor(en_model_1, it_model_1, test_en)

# %%
# create a dataframe from the resulting list

df_unigram_res = pd.DataFrame(unigram_res,columns = ['word','en_prob','it_prob','english','language prediction'])

df_unigram_res.head(20)
# Out:
#         word       en_prob       it_prob  english language prediction
# 0          a  7.918890e-02  1.073034e-01        0             Italian
# 1        for  1.315209e-04  8.902523e-05        1             English
# 2         of  2.177298e-03  1.260994e-03        1             English
# 3       your  5.783464e-06  2.168563e-04        0             Italian
# 4          a  7.918890e-02  1.073034e-01        0             Italian
# 5     street  3.802466e-07  2.225793e-07        1             English
# 6     easier  2.778611e-07  5.554455e-07        0             Italian
# 7       help  6.315489e-06  1.923168e-06        1             English
# 8   physical  1.494797e-11  3.788034e-10        0             Italian
# 9   thoughts  6.026386e-11  6.365914e-13        1             English
# 10        is  3.965880e-03  5.136522e-03        0             Italian
# 11        on  5.959892e-03  6.240304e-03        0             Italian
# 12     areas  2.730068e-06  4.492230e-06        0             Italian
# 13       for  1.315209e-04  8.902523e-05        1             English
# 14      down  3.128035e-06  2.255391e-04        0             Italian
# 15        to  7.343767e-03  5.965472e-03        1             English
# 16  websites  6.458665e-11  1.974877e-09        0             Italian
# 17    pizzas  8.551320e-12  1.338435e-09        0             Italian
# 18     other  2.589811e-06  3.863375e-07        1             English
# 19   travels  1.668981e-09  2.540303e-09        0             Italian

# %%
# count the number of words classified as an english word
unigram_eng_pos = df_unigram_res.english.sum()

# count the total number of words in the english test list of words
unigram_total_words = len(df_unigram_res.index)

# calculate the accuracy of the unigram model
unigram_model_accuracy = unigram_eng_pos/unigram_total_words

unigram_model_accuracy
# Out:
# 0.3688212927756654

# %% [markdown]
# #### ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Creating the Bigram Model

# %%
# Create an empty dictionary inside of a dictionary
en_model_2 = defaultdict(lambda: defaultdict(lambda: 0))

# loop through the words in the english training list of words 
for words in train_en:
    
    # using the ngrams package loop through the bigrams and create a dictionary of counts for each bigram
    for let1, let2 in ngrams(words, 2):
        en_model_2[(let1)][let2] += 1


# transform the counts to probabilities
#loop through each key letter in the bigram model
for let1 in en_model_2:
    
    # creates a total count of the values under the key letter
    total_count = float(sum(en_model_2[let1].values()))
    
    # loops through the second letters of the bigrams for each first letter
    for let2 in en_model_2[let1]:
        
        # divides the second letter count by the total count of the first letter in the bigram 
        en_model_2[let1][let2] /= total_count
        
        
en_model_2
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'x': 0.019444444444444445,
#                           'r': 0.18055555555555555,
#                           's': 0.14722222222222223,
#                           'o': 0.013888888888888888,
#                           'c': 0.03888888888888889,
#                           'd': 0.075,
#                           'b': 0.002777777777777778,
#                           'a': 0.09166666666666666,
#                           'n': 0.14722222222222223,
#                           'm': 0.027777777777777776,
#                           'i': 0.016666666666666666,
#                           't': 0.03611111111111111,
#                           'l': 0.06666666666666667,
#                           'e': 0.03611111111111111,
#                           'g': 0.011111111111111112,
#                           'v': 0.030555555555555555,
#                           'f': 0.005555555555555556,
#                           'y': 0.022222222222222223,
#                           'w': 0.016666666666666666,
#                           'p': 0.011111111111111112,
#                           'h': 0.002777777777777778}),
#              'x': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'p': 0.5, 'i': 0.25, 'a': 0.125, 't': 0.125}),
#              'p': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 0.1782178217821782,
#                           'h': 0.0297029702970297,
#                           'p': 0.0297029702970297,
#                           'i': 0.0891089108910891,
#                           'r': 0.0594059405940594,
#                           'e': 0.2376237623762376,
#                           'l': 0.1782178217821782,
#                           'o': 0.10891089108910891,
#                           'u': 0.06930693069306931,
#                           's': 0.009900990099009901,
#                           'y': 0.009900990099009901}),
#              'a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'n': 0.24127906976744187,
#                           'b': 0.01744186046511628,
#                           't': 0.12209302325581395,
#                           'p': 0.011627906976744186,
#                           'l': 0.09593023255813954,
#                           'c': 0.07267441860465117,
#                           'w': 0.014534883720930232,
#                           's': 0.055232558139534885,
#                           'v': 0.03197674418604651,
#                           'i': 0.03488372093023256,
#                           'r': 0.13953488372093023,
#                           'm': 0.02616279069767442,
#                           'k': 0.03488372093023256,
#                           'd': 0.03488372093023256,
#                           'g': 0.01744186046511628,
#                           'y': 0.02616279069767442,
#                           'u': 0.0029069767441860465,
#                           'f': 0.01744186046511628,
#                           'x': 0.0029069767441860465}),
#              'n': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'d': 0.1896551724137931,
#                           'a': 0.01293103448275862,
#                           'e': 0.10775862068965517,
#                           't': 0.17672413793103448,
#                           'g': 0.1939655172413793,
#                           'o': 0.04310344827586207,
#                           'n': 0.02586206896551724,
#                           'c': 0.021551724137931036,
#                           'y': 0.04741379310344827,
#                           'i': 0.03017241379310345,
#                           's': 0.07758620689655173,
#                           'u': 0.02586206896551724,
#                           'v': 0.021551724137931036,
#                           'm': 0.004310344827586207,
#                           'k': 0.01293103448275862,
#                           'f': 0.004310344827586207,
#                           'h': 0.004310344827586207}),
#              'b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'o': 0.23880597014925373,
#                           'e': 0.26865671641791045,
#                           'u': 0.04477611940298507,
#                           'l': 0.07462686567164178,
#                           'a': 0.1044776119402985,
#                           'y': 0.08955223880597014,
#                           'r': 0.07462686567164178,
#                           'b': 0.029850746268656716,
#                           'i': 0.05970149253731343,
#                           't': 0.014925373134328358}),
#              'o': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 0.25833333333333336,
#                           's': 0.016666666666666666,
#                           'f': 0.09166666666666666,
#                           'n': 0.11944444444444445,
#                           'p': 0.022222222222222223,
#                           'r': 0.125,
#                           'm': 0.06111111111111111,
#                           't': 0.05,
#                           'o': 0.05555555555555555,
#                           'k': 0.030555555555555555,
#                           'i': 0.016666666666666666,
#                           'v': 0.03333333333333333,
#                           'w': 0.025,
#                           'a': 0.008333333333333333,
#                           'd': 0.022222222222222223,
#                           'g': 0.005555555555555556,
#                           'c': 0.016666666666666666,
#                           'l': 0.022222222222222223,
#                           'b': 0.005555555555555556,
#                           'y': 0.008333333333333333,
#                           'e': 0.002777777777777778,
#                           'x': 0.002777777777777778}),
#              'u': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'t': 0.13970588235294118,
#                           'n': 0.08823529411764706,
#                           'r': 0.3014705882352941,
#                           'p': 0.022058823529411766,
#                           'i': 0.029411764705882353,
#                           'l': 0.0661764705882353,
#                           'b': 0.029411764705882353,
#                           'c': 0.04411764705882353,
#                           's': 0.1323529411764706,
#                           'f': 0.03676470588235294,
#                           'e': 0.014705882352941176,
#                           'g': 0.03676470588235294,
#                           'd': 0.014705882352941176,
#                           'a': 0.029411764705882353,
#                           'm': 0.014705882352941176}),
#              'h': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 0.16751269035532995,
#                           'e': 0.5431472081218274,
#                           'o': 0.1116751269035533,
#                           'i': 0.116751269035533,
#                           't': 0.015228426395939087,
#                           'l': 0.005076142131979695,
#                           'r': 0.02030456852791878,
#                           'y': 0.005076142131979695,
#                           'u': 0.01015228426395939,
#                           's': 0.005076142131979695}),
#              't': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'h': 0.34810126582278483,
#                           'm': 0.0031645569620253164,
#                           'o': 0.12974683544303797,
#                           'e': 0.15822784810126583,
#                           'i': 0.0981012658227848,
#                           'y': 0.028481012658227847,
#                           'a': 0.06645569620253164,
#                           't': 0.03164556962025317,
#                           'r': 0.05063291139240506,
#                           's': 0.028481012658227847,
#                           'u': 0.02531645569620253,
#                           'c': 0.00949367088607595,
#                           'n': 0.0031645569620253164,
#                           'l': 0.012658227848101266,
#                           'w': 0.0031645569620253164,
#                           'p': 0.0031645569620253164}),
#              'm': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'o': 0.13725490196078433,
#                           'e': 0.3431372549019608,
#                           'a': 0.20588235294117646,
#                           'i': 0.12745098039215685,
#                           'y': 0.00980392156862745,
#                           'p': 0.06862745098039216,
#                           'u': 0.058823529411764705,
#                           's': 0.0196078431372549,
#                           'b': 0.00980392156862745,
#                           'f': 0.00980392156862745,
#                           'm': 0.00980392156862745}),
#              's': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'p': 0.07017543859649122,
#                           's': 0.07602339181286549,
#                           'i': 0.07602339181286549,
#                           'o': 0.1286549707602339,
#                           't': 0.23976608187134502,
#                           'u': 0.04678362573099415,
#                           'e': 0.1695906432748538,
#                           'h': 0.09941520467836257,
#                           'l': 0.023391812865497075,
#                           'y': 0.005847953216374269,
#                           'm': 0.017543859649122806,
#                           'k': 0.005847953216374269,
#                           'a': 0.04093567251461988}),
#              'r': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.2994652406417112,
#                           'o': 0.0962566844919786,
#                           'a': 0.0748663101604278,
#                           'k': 0.016042780748663103,
#                           'y': 0.06951871657754011,
#                           'n': 0.0213903743315508,
#                           'b': 0.0213903743315508,
#                           's': 0.0855614973262032,
#                           'd': 0.0374331550802139,
#                           'i': 0.09090909090909091,
#                           'c': 0.016042780748663103,
#                           't': 0.06951871657754011,
#                           'w': 0.0053475935828877,
#                           'u': 0.026737967914438502,
#                           'g': 0.026737967914438502,
#                           'm': 0.016042780748663103,
#                           'r': 0.0053475935828877,
#                           'v': 0.016042780748663103,
#                           'l': 0.0053475935828877}),
#              'i': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.05466237942122187,
#                           'n': 0.3183279742765273,
#                           'o': 0.05144694533762058,
#                           'l': 0.08038585209003216,
#                           'f': 0.04823151125401929,
#                           'c': 0.04823151125401929,
#                           't': 0.09003215434083602,
#                           'd': 0.02572347266881029,
#                           's': 0.10289389067524116,
#                           'r': 0.05144694533762058,
#                           'g': 0.022508038585209004,
#                           'z': 0.012861736334405145,
#                           'v': 0.022508038585209004,
#                           'm': 0.04180064308681672,
#                           'p': 0.00964630225080386,
#                           'k': 0.006430868167202572,
#                           'a': 0.00964630225080386,
#                           'u': 0.003215434083601286}),
#              'c': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 0.21739130434782608,
#                           'o': 0.1956521739130435,
#                           't': 0.07971014492753623,
#                           'e': 0.13043478260869565,
#                           'r': 0.021739130434782608,
#                           'k': 0.050724637681159424,
#                           'h': 0.16666666666666666,
#                           'l': 0.036231884057971016,
#                           'u': 0.07246376811594203,
#                           'i': 0.021739130434782608,
#                           'y': 0.007246376811594203}),
#              'f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.24390243902439024,
#                           'a': 0.036585365853658534,
#                           'u': 0.036585365853658534,
#                           'l': 0.06097560975609756,
#                           'i': 0.13414634146341464,
#                           'f': 0.14634146341463414,
#                           'r': 0.04878048780487805,
#                           'o': 0.21951219512195122,
#                           't': 0.04878048780487805,
#                           's': 0.012195121951219513,
#                           'y': 0.012195121951219513}),
#              'l': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.1744186046511628,
#                           'k': 0.023255813953488372,
#                           'a': 0.12790697674418605,
#                           'y': 0.06976744186046512,
#                           'l': 0.18023255813953487,
#                           'd': 0.10465116279069768,
#                           'o': 0.09302325581395349,
#                           's': 0.023255813953488372,
#                           'i': 0.12790697674418605,
#                           'p': 0.03488372093023256,
#                           't': 0.005813953488372093,
#                           'f': 0.011627906976744186,
#                           'é': 0.005813953488372093,
#                           'v': 0.005813953488372093,
#                           'u': 0.011627906976744186}),
#              'd': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.3382352941176471,
#                           'i': 0.20588235294117646,
#                           'o': 0.10294117647058823,
#                           's': 0.08823529411764706,
#                           'y': 0.04411764705882353,
#                           'd': 0.07352941176470588,
#                           'l': 0.04411764705882353,
#                           'v': 0.014705882352941176,
#                           'a': 0.014705882352941176,
#                           'u': 0.014705882352941176,
#                           'r': 0.058823529411764705}),
#              'y': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'o': 0.8266666666666667,
#                           's': 0.02666666666666667,
#                           'i': 0.04,
#                           'e': 0.05333333333333334,
#                           'p': 0.04,
#                           't': 0.013333333333333334}),
#              'w': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'s': 0.031746031746031744,
#                           'i': 0.31746031746031744,
#                           'o': 0.09523809523809523,
#                           'a': 0.20634920634920634,
#                           'e': 0.06349206349206349,
#                           'h': 0.23809523809523808,
#                           'n': 0.031746031746031744,
#                           't': 0.015873015873015872}),
#              'g': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'l': 0.02,
#                           'i': 0.1,
#                           'h': 0.14,
#                           'a': 0.2,
#                           'r': 0.12,
#                           'o': 0.04,
#                           'g': 0.04,
#                           'e': 0.24,
#                           'y': 0.02,
#                           's': 0.02,
#                           'b': 0.02,
#                           'u': 0.02,
#                           'n': 0.02}),
#              'v': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.6779661016949152,
#                           'o': 0.06779661016949153,
#                           'a': 0.0847457627118644,
#                           'i': 0.1694915254237288}),
#              'k': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.52,
#                           'i': 0.24,
#                           's': 0.16,
#                           'l': 0.04,
#                           'w': 0.04}),
#              'z': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.4, 'a': 0.4, 'z': 0.2}),
#              '3': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'0': 1.0}),
#              'q': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 1.0}),
#              'j': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 0.5, 'o': 0.25, 'i': 0.25})})

# %%
# Create an empty dictionary inside of a dictionary
it_model_2 = defaultdict(lambda: defaultdict(lambda: 0))

# loop through the words in the italian training list of words 
for words in train_it:
    
    # using the ngrams package loop through the bigrams and create a dictionary of counts for each bigram
    for let1, let2 in ngrams(words, 2):
        it_model_2[(let1)][let2] += 1


# transform the counts to probabilities
#loop through each key letter in the bigram model
for let1 in it_model_2:
    
    # creates a total count of the values under the key letter
    total_count = float(sum(it_model_2[let1].values()))
    
    # loops through the second letters of the bigrams for each first letter
    for let2 in it_model_2[let1]:
            
        # divides the second letter count by the total count of the first letter in the bigram 
        it_model_2[let1][let2] /= total_count
        
        
it_model_2
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'c': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'h': 0.14601769911504425,
#                           'u': 0.07079646017699115,
#                           'i': 0.15486725663716813,
#                           'a': 0.11946902654867257,
#                           'e': 0.11946902654867257,
#                           'o': 0.2831858407079646,
#                           'r': 0.022123893805309734,
#                           'c': 0.06637168141592921,
#                           'q': 0.008849557522123894,
#                           'l': 0.008849557522123894}),
#              'h': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.5121951219512195,
#                           'a': 0.14634146341463414,
#                           'i': 0.3170731707317073,
#                           'é': 0.024390243902439025}),
#              'd': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.31746031746031744,
#                           'i': 0.3439153439153439,
#                           'o': 0.15343915343915343,
#                           'u': 0.047619047619047616,
#                           'a': 0.1111111111111111,
#                           'd': 0.005291005291005291,
#                           'r': 0.015873015873015872,
#                           'k': 0.005291005291005291}),
#              'e': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'l': 0.1309192200557103,
#                           'n': 0.21727019498607242,
#                           'r': 0.2646239554317549,
#                           't': 0.0807799442896936,
#                           'i': 0.016713091922005572,
#                           'm': 0.027855153203342618,
#                           's': 0.10863509749303621,
#                           'd': 0.022284122562674095,
#                           'g': 0.027855153203342618,
#                           'a': 0.022284122562674095,
#                           'v': 0.04178272980501393,
#                           'z': 0.008356545961002786,
#                           'b': 0.005571030640668524,
#                           'o': 0.002785515320334262,
#                           'c': 0.008356545961002786,
#                           'e': 0.002785515320334262,
#                           'f': 0.005571030640668524,
#                           'p': 0.005571030640668524}),
#              'l': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'l': 0.17358490566037735,
#                           'e': 0.2037735849056604,
#                           'u': 0.03773584905660377,
#                           'a': 0.2339622641509434,
#                           't': 0.04905660377358491,
#                           'i': 0.13962264150943396,
#                           'o': 0.09811320754716982,
#                           'm': 0.026415094339622643,
#                           'p': 0.011320754716981131,
#                           'c': 0.026415094339622643}),
#              'u': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'r': 0.053475935828877004,
#                           'l': 0.0374331550802139,
#                           'm': 0.026737967914438502,
#                           'n': 0.25668449197860965,
#                           's': 0.0374331550802139,
#                           'p': 0.03208556149732621,
#                           'a': 0.13368983957219252,
#                           'i': 0.053475935828877004,
#                           'f': 0.016042780748663103,
#                           't': 0.11764705882352941,
#                           'd': 0.0106951871657754,
#                           'c': 0.026737967914438502,
#                           'ò': 0.0106951871657754,
#                           'o': 0.09090909090909091,
#                           'e': 0.08021390374331551,
#                           'z': 0.0106951871657754,
#                           'b': 0.0053475935828877}),
#              'r': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'r': 0.019337016574585635,
#                           'i': 0.16298342541436464,
#                           'e': 0.3397790055248619,
#                           's': 0.019337016574585635,
#                           'a': 0.1464088397790055,
#                           't': 0.08839779005524862,
#                           'c': 0.027624309392265192,
#                           'b': 0.013812154696132596,
#                           'à': 0.008287292817679558,
#                           'f': 0.0027624309392265192,
#                           'g': 0.011049723756906077,
#                           'n': 0.011049723756906077,
#                           'o': 0.06906077348066299,
#                           'p': 0.008287292817679558,
#                           'm': 0.022099447513812154,
#                           'u': 0.011049723756906077,
#                           'l': 0.019337016574585635,
#                           'v': 0.0027624309392265192,
#                           'd': 0.013812154696132596,
#                           'z': 0.0027624309392265192}),
#              'i': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'c': 0.09762532981530343,
#                           'n': 0.19261213720316622,
#                           'm': 0.036939313984168866,
#                           'r': 0.044854881266490766,
#                           'e': 0.0395778364116095,
#                           's': 0.0395778364116095,
#                           'g': 0.018469656992084433,
#                           'o': 0.12137203166226913,
#                           'a': 0.10290237467018469,
#                           'v': 0.036939313984168866,
#                           'd': 0.018469656992084433,
#                           'ù': 0.023746701846965697,
#                           'u': 0.013192612137203167,
#                           'z': 0.0316622691292876,
#                           'p': 0.0079155672823219,
#                           't': 0.0712401055408971,
#                           'l': 0.08179419525065963,
#                           'b': 0.0079155672823219,
#                           'f': 0.010554089709762533,
#                           'ò': 0.002638522427440633}),
#              'm': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.26666666666666666,
#                           'a': 0.2518518518518518,
#                           'i': 0.07407407407407407,
#                           'o': 0.18518518518518517,
#                           'b': 0.05185185185185185,
#                           'p': 0.11851851851851852,
#                           'm': 0.022222222222222223,
#                           'u': 0.02962962962962963}),
#              'n': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'t': 0.17737003058103976,
#                           'a': 0.12844036697247707,
#                           'c': 0.03363914373088685,
#                           's': 0.024464831804281346,
#                           'o': 0.1620795107033639,
#                           'e': 0.14067278287461774,
#                           'd': 0.10703363914373089,
#                           'g': 0.021406727828746176,
#                           'i': 0.0764525993883792,
#                           'u': 0.01529051987767584,
#                           'q': 0.01529051987767584,
#                           'n': 0.04892966360856269,
#                           'z': 0.024464831804281346,
#                           'v': 0.01529051987767584,
#                           'f': 0.009174311926605505}),
#              't': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'r': 0.08672086720867209,
#                           'i': 0.1951219512195122,
#                           't': 0.11924119241192412,
#                           'e': 0.16802168021680217,
#                           'o': 0.14634146341463414,
#                           'a': 0.16531165311653118,
#                           'u': 0.0921409214092141,
#                           'à': 0.018970189701897018,
#                           'c': 0.0027100271002710027,
#                           'n': 0.0027100271002710027,
#                           'm': 0.0027100271002710027}),
#              's': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'i': 0.11740890688259109,
#                           'u': 0.06477732793522267,
#                           'o': 0.13360323886639677,
#                           'a': 0.11336032388663968,
#                           'e': 0.12550607287449392,
#                           't': 0.1862348178137652,
#                           'c': 0.06477732793522267,
#                           'p': 0.044534412955465584,
#                           's': 0.12550607287449392,
#                           'b': 0.004048582995951417,
#                           'g': 0.004048582995951417,
#                           'v': 0.004048582995951417,
#                           'm': 0.004048582995951417,
#                           'ì': 0.004048582995951417,
#                           'q': 0.004048582995951417}),
#              'p': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.24607329842931938,
#                           'r': 0.2198952879581152,
#                           's': 0.010471204188481676,
#                           'p': 0.03664921465968586,
#                           'o': 0.18324607329842932,
#                           'i': 0.13612565445026178,
#                           'a': 0.10471204188481675,
#                           'l': 0.03664921465968586,
#                           'u': 0.02617801047120419}),
#              'o': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'n': 0.26855123674911663,
#                           'r': 0.19434628975265017,
#                           'v': 0.03180212014134275,
#                           'l': 0.1166077738515901,
#                           'g': 0.0353356890459364,
#                           'm': 0.053003533568904596,
#                           's': 0.11307420494699646,
#                           'z': 0.0035335689045936395,
#                           't': 0.04240282685512368,
#                           'f': 0.028268551236749116,
#                           'c': 0.028268551236749116,
#                           'p': 0.03180212014134275,
#                           'i': 0.0176678445229682,
#                           'b': 0.014134275618374558,
#                           'd': 0.0176678445229682,
#                           'o': 0.0035335689045936395}),
#              'a': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'r': 0.18933333333333333,
#                           'l': 0.12533333333333332,
#                           'm': 0.07466666666666667,
#                           'n': 0.17333333333333334,
#                           'i': 0.034666666666666665,
#                           'g': 0.04,
#                           'z': 0.021333333333333333,
#                           'p': 0.021333333333333333,
#                           's': 0.050666666666666665,
#                           't': 0.112,
#                           'b': 0.013333333333333334,
#                           'd': 0.024,
#                           'v': 0.042666666666666665,
#                           'f': 0.016,
#                           'c': 0.04533333333333334,
#                           'u': 0.010666666666666666,
#                           'e': 0.005333333333333333}),
#              'f': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'i': 0.24358974358974358,
#                           'f': 0.21794871794871795,
#                           'e': 0.1282051282051282,
#                           'r': 0.0641025641025641,
#                           'o': 0.1282051282051282,
#                           'a': 0.1794871794871795,
#                           'u': 0.038461538461538464}),
#              'g': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'l': 0.15476190476190477,
#                           'i': 0.2619047619047619,
#                           'r': 0.08333333333333333,
#                           'u': 0.047619047619047616,
#                           'n': 0.05952380952380952,
#                           'a': 0.08333333333333333,
#                           'e': 0.10714285714285714,
#                           'g': 0.15476190476190477,
#                           'h': 0.023809523809523808,
#                           'o': 0.023809523809523808}),
#              'v': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'r': 0.05,
#                           'i': 0.275,
#                           'e': 0.2625,
#                           'o': 0.1875,
#                           'v': 0.0125,
#                           'a': 0.1875,
#                           'u': 0.025}),
#              'b': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'e': 0.13636363636363635,
#                           'i': 0.36363636363636365,
#                           'a': 0.29545454545454547,
#                           'b': 0.06818181818181818,
#                           'r': 0.06818181818181818,
#                           'u': 0.045454545454545456,
#                           'l': 0.022727272727272728}),
#              'z': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'i': 0.5454545454545454,
#                           'z': 0.18181818181818182,
#                           'o': 0.045454545454545456,
#                           'e': 0.06818181818181818,
#                           'a': 0.1590909090909091}),
#              'q': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'u': 1.0}),
#              '3': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'0': 1.0}),
#              'k': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'a': 1.0}),
#              '1': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'2': 1.0}),
#              '2': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#                          {'5': 1.0})})

# %%
# predictor function that uses bigram model to predict the language of the words in the English test list of words
def bigram_language_predictor(en_model,it_model, test_listofwords):
    
    # create empty results list to be appended to
    results = []
    
    # loop that goes through all of the words in the test list of words
    for word in test_listofwords:
        
        # initially setting the probability of the word being engluish and italian to 1    
        en_prob = 1
        it_prob =1
        
        # looping through the bigrams in each word
        for let1, let2 in ngrams(word, 2):
            # if else clause incase the letter is not a key in the dictionary from the english training list of words
            if let1 not in en_model.keys():
                en_prob = en_prob
            else: 
                # model creates a probability of if the test word is english by multiplying the bigram frequncies together
                en_prob = en_prob*en_model[let1][let2]
            
            
            # if else clause incase the letter is not a letter key in the dictionary from the italian training list of words    
            if let1 not in it_model.keys():
                it_prob = it_prob
            else:
                # model creates a probability of the word being italian by multiplying the letter frequncies together    
                it_prob = it_prob*it_model[let1][let2]
        
        # if else statement to flag which language has a higher probability and assign that language to a variable
        if en_prob >= it_prob:
            en_flag = 1
            pred_lang= 'English'
        else:
            en_flag = 0
            pred_lang = 'Italian'
        
        # append the results to a results list created at the start of the function
        results.append([word, en_prob, it_prob, en_flag, pred_lang])
            
    return results

# %%
# run predictor using the english and italian bigram frequency dictionaries and the english test list of words
bigram_res = bigram_language_predictor(en_model_2,it_model_2, test_en)

bigram_res
# Out:
# [['a', 1, 1, 1, 'English'],
#  ['for', 0.027439024390243903, 0.024916190993929506, 1, 'English'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['street', 4.74076873398168e-06, 1.234781551602595e-06, 1, 'English'],
#  ['easier', 3.7988594656206426e-06, 1.388353700182376e-06, 1, 'English'],
#  ['help', 0.0012631330421437846, 0.0007591266326286009, 1, 'English'],
#  ['physical', 3.0745259615610137e-10, 0.0, 1, 'English'],
#  ['thoughts', 2.2418786031029916e-08, 0.0, 1, 'English'],
#  ['is', 0.10289389067524116, 0.0395778364116095, 1, 'English'],
#  ['on', 0.11944444444444445, 0.26855123674911663, 0, 'Italian'],
#  ['areas', 0.00021156109820888872, 7.26342561955914e-05, 1, 'English'],
#  ['for', 0.027439024390243903, 0.024916190993929506, 1, 'English'],
#  ['down', 8.169934640522875e-05, 0.0, 1, 'English'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['websites', 0.0, 0.0, 1, 'English'],
#  ['pizzas', 5.064142098050379e-06, 6.316653059817202e-06, 0, 'Italian'],
#  ['other', 0.0017068840269299694, 0.0, 1, 'English'],
#  ['travels', 1.2740950745989375e-07, 0.0, 1, 'English'],
#  ['ones', 0.0018949220412941678, 0.004104000398046862, 0, 'Italian'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['this', 0.004181737830244171, 0.0, 1, 'English'],
#  ['interest', 1.698916329274545e-05, 1.0442054338816207e-05, 1, 'English'],
#  ['get', 0.008666666666666666, 0.0086549940310386, 1, 'English'],
#  ['together', 2.132604750008611e-07, 0.0, 1, 'English'],
#  ['company', 1.67293168794644e-06, 0.0, 1, 'English'],
#  ['firm', 0.00011071795983706008, 0.0002414627409160857, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['feel', 0.0005871725383920505, 4.675352476812738e-05, 1, 'English'],
#  ['part', 0.0017287638476569955, 0.0017525286126136548, 0, 'Italian'],
#  ['not', 0.002155172413793104, 0.006872629429117904, 0, 'Italian'],
#  ['opening', 1.4483052753356206e-06, 5.359779363508923e-07, 1, 'English'],
#  ['affairs', 1.4339314068493289e-08, 1.8819973163330935e-08, 0, 'Italian'],
#  ['more', 0.005137884030617595, 0.01222866464066706, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['bring', 0.0004188917922859369, 4.58190369650282e-05, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['cool', 0.00024154589371980676, 0.00011668434795493552, 1, 'English'],
#  ['most', 0.0005484845010128808, 0.003899695177359302, 0, 'Italian'],
#  ['score', 0.0, 0.0012113436279071437, 0, 'Italian'],
#  ['oatmeal', 9.715324884480701e-09, 0.0, 1, 'English'],
#  ['consider', 2.165418146219084e-07, 3.389373296718482e-07, 0, 'Italian'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['take', 0.0012054754194877834, 0.0, 1, 'English'],
#  ['insult', 4.4455792485382037e-07, 5.605351167448457e-07, 0, 'Italian'],
#  ['dinner', 3.297767804029671e-05, 0.00012065537348962432, 0, 'Italian'],
#  ['body', 0.0002341235001463272, 0.0, 1, 'English'],
#  ['for', 0.027439024390243903, 0.024916190993929506, 1, 'English'],
#  ['adults', 5.621399772433744e-09, 0.0, 1, 'English'],
#  ['strong', 2.7073351922370765e-05, 6.411997920466063e-06, 1, 'English'],
#  ['and', 0.0457598235765838, 0.01855249745158002, 1, 'English'],
#  ['years', 5.836753305973552e-05, 8.158533269723039e-05, 0, 'Italian'],
#  ['fertilizer', 2.8684524775893925e-09, 3.817685927582488e-09, 0, 'Italian'],
#  ['out', 0.03609068627450981, 0.0, 1, 'English'],
#  ['dog', 0.0005718954248366013, 0.005421878213397648, 0, 'Italian'],
#  ['this', 0.004181737830244171, 0.0, 1, 'English'],
#  ['decide', 2.487912761725332e-06, 2.408929742602894e-06, 1, 'English'],
#  ['not', 0.002155172413793104, 0.006872629429117904, 0, 'Italian'],
#  ['interest', 1.698916329274545e-05, 1.0442054338816207e-05, 1, 'English'],
#  ['meals', 7.017240373704917e-05, 0.0, 1, 'English'],
#  ['about', 0.00015032566306633728, 0.0, 1, 'English'],
#  ['can', 0.052451971688574316, 0.020707964601769914, 1, 'English'],
#  ['take', 0.0012054754194877834, 0.0, 1, 'English'],
#  ['wrist', 0.0, 0.0012013135305557093, 0, 'Italian'],
#  ['worth', 0.00028808991951210865, 0.0, 1, 'English'],
#  ['part', 0.0017287638476569955, 0.0017525286126136548, 0, 'Italian'],
#  ['got', 0.002, 0.0010095911155981827, 1, 'English'],
#  ['trauma', 3.336346103796772e-08, 9.119965200557312e-07, 0, 'Italian'],
#  ['dough', 0.00013687644175317188, 0.0, 1, 'English'],
#  ['insurance', 1.7688038213418115e-08, 1.6647803949872526e-09, 1, 'English'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['credit', 9.05037589623678e-06, 4.104211672351806e-06, 1, 'English'],
#  ['time', 0.0014071015682922605, 0.0019220456056803312, 0, 'Italian'],
#  ['can', 0.052451971688574316, 0.020707964601769914, 1, 'English'],
#  ['club', 1.2391205218184342e-05, 1.7858051704417097e-06, 1, 'English'],
#  ['leave', 0.00034661429448808797, 5.085825406001997e-05, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['and', 0.0457598235765838, 0.01855249745158002, 1, 'English'],
#  ['just', 0.01586687306501548, 0.006971356816558054, 1, 'English'],
#  ['stories', 2.8448786724575356e-06, 3.7116769911950006e-06, 0, 'Italian'],
#  ['that', 0.007119412619973731, 0.0, 1, 'English'],
#  ['around', 5.8063227177752565e-05, 0.0, 1, 'English'],
#  ['or', 0.125, 0.19434628975265017, 0, 'Italian'],
#  ['art', 0.009700286034075363, 0.016736648250460402, 0, 'Italian'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['comes', 0.0006040127403618452, 0.0004348257443668857, 1, 'English'],
#  ['are', 0.04178584753140156, 0.06433149171270719, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['help', 0.0012631330421437846, 0.0007591266326286009, 1, 'English'],
#  ['level', 0.0002408794288967722, 0.0002926020829804531, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['back', 0.0003851445502517745, 0.0, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['growth', 1.595574938836294e-06, 0.0, 1, 'English'],
#  ['work', 0.00019098548510313216, 0.0, 1, 'English'],
#  ['hitting', 2.014865753318948e-06, 2.166957670596171e-06, 0, 'Italian'],
#  ['life', 0.0015046699483670226, 0.00018892178000058717, 1, 'English'],
#  ['kiss', 0.0018773622158289613, 0.0, 1, 'English'],
#  ['health', 9.66633058059833e-06, 0.0, 1, 'English'],
#  ['golf', 1.03359173126615e-05, 0.0, 1, 'English'],
#  ['shares', 0.00010244791138117595, 0.0, 1, 'English'],
#  ['hide', 0.0010158044969991523, 0.001859121493589606, 0, 'Italian'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['ball', 0.001806391918180864, 0.006427901658090337, 0, 'Italian'],
#  ['shoes', 4.540253832760338e-06, 0.0, 1, 'English'],
#  ['throat', 6.922131861909315e-07, 0.0, 1, 'English'],
#  ['irritation', 1.1014027686372522e-11, 1.185879540595664e-09, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['their', 0.00016211809704207473, 0.0, 1, 'English'],
#  ['films', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['ve', 0.6779661016949152, 0.2625, 1, 'English'],
#  ['look', 0.00015790984783232843, 0.0, 1, 'English'],
#  ['sound', 0.0005561783091942162, 0.0, 1, 'English'],
#  ['good', 4.938271604938272e-05, 1.4864415718465586e-06, 1, 'English'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['or', 0.125, 0.19434628975265017, 0, 'Italian'],
#  ['and', 0.0457598235765838, 0.01855249745158002, 1, 'English'],
#  ['for', 0.027439024390243903, 0.024916190993929506, 1, 'English'],
#  ['benefit', 2.859743391078505e-07, 4.0292842532470735e-07, 0, 'Italian'],
#  ['rent', 0.007791402872538775, 0.013094138670912876, 0, 'Italian'],
#  ['watch', 3.986360514179177e-05, 4.4319735232750564e-05, 0, 'Italian'],
#  ['any', 0.01143995589414595, 0.0, 1, 'English'],
#  ['each', 0.0011103036175710594, 0.00014750905908743564, 1, 'English'],
#  ['here', 0.029368030861013833, 0.046053340309946296, 0, 'Italian'],
#  ['overall', 5.281688136719581e-06, 7.036559840996739e-06, 0, 'Italian'],
#  ['data', 0.0001193202479696618, 0.0020572116832279436, 0, 'Italian'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['designs', 1.3221834019096558e-07, 1.0890615667392819e-07, 1, 'English'],
#  ['into', 0.007299068703061468, 0.004999554243805613, 1, 'English'],
#  ['protect', 1.4023384273744154e-07, 0.0, 1, 'English'],
#  ['enemies', 4.5198911240852946e-07, 2.7114663780830477e-07, 1, 'English'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['as', 0.055232558139534885, 0.050666666666666665, 1, 'English'],
#  ['include', 1.4376703043679514e-08, 7.346527363874887e-09, 1, 'English'],
#  ['possibilities', 0.0, 5.998526503178279e-13, 0, 'Italian'],
#  ['having', 5.605692606382344e-05, 7.079828538354615e-06, 1, 'English'],
#  ['leave', 0.00034661429448808797, 5.085825406001997e-05, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['support', 2.9010764528979174e-08, 2.398002794517944e-07, 0, 'Italian'],
#  ['emotions', 8.916205045176424e-09, 3.4033040080665036e-08, 0, 'Italian'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['embroidery', 3.5606829108474193e-12, 0.0, 1, 'English'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['dozens', 0.0, 1.9649917207934023e-07, 0, 'Italian'],
#  ['half', 0.00018685501560728392, 0.0, 1, 'English'],
#  ['doctor', 2.2179832536573606e-06, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['as', 0.055232558139534885, 0.050666666666666665, 1, 'English'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['from', 0.00028694404591104734, 0.00023464519394082286, 1, 'English'],
#  ['physically', 3.866021017106196e-12, 0.0, 1, 'English'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['find', 0.008098756284158916, 0.005021840791974655, 1, 'English'],
#  ['adventure', 2.0681659529763e-08, 0.0, 1, 'English'],
#  ['that', 0.007119412619973731, 0.0, 1, 'English'],
#  ['will', 0.0045994119874326255, 0.014198237666152237, 0, 'Italian'],
#  ['dress', 0.00019715968237791828, 7.353445711263338e-05, 1, 'English'],
#  ['contact', 1.5899149072787494e-06, 0.0, 1, 'English'],
#  ['loan', 0.0001870380385794123, 0.0, 1, 'English'],
#  ['crisis', 1.59065466562363e-06, 6.631475189256543e-07, 1, 'English'],
#  ['want', 0.008798696236045874, 0.030744138634046892, 0, 'Italian'],
#  ['some', 0.002697830269209698, 0.001888385001645184, 1, 'English'],
#  ['learn', 4.77205484681704e-05, 9.499963268248928e-06, 1, 'English'],
#  ['simply', 2.71163982673112e-06, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['connect', 2.0188546640597742e-07, 0.0, 1, 'English'],
#  ['relaxing', 1.1458566667743818e-07, 0.0, 1, 'English'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['any', 0.01143995589414595, 0.0, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['disturb', 8.292064967846998e-07, 1.7251897061195783e-07, 1, 'English'],
#  ['s', 1, 1, 1, 'English'],
#  ['anyone', 0.0001217230300678205, 0.0, 1, 'English'],
#  ['rate', 0.0014463060359959006, 0.002755184236925242, 0, 'Italian'],
#  ['if', 0.04823151125401929, 0.010554089709762533, 1, 'English'],
#  ['with', 0.009949303774856302, 0.0, 1, 'English'],
#  ['smaller', 1.9666934673716766e-06, 1.1961999662893426e-06, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['vodka', 0.0, 1.7527623534690674e-05, 0, 'Italian'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['making', 0.00010642716721000458, 0.0, 1, 'English'],
#  ['person', 5.6412016617325064e-05, 4.51780269607033e-05, 1, 'English'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['or', 0.125, 0.19434628975265017, 0, 'Italian'],
#  ['variety', 6.043561042904633e-08, 0.0, 1, 'English'],
#  ['browns', 4.4232356302835545e-07, 0.0, 1, 'English'],
#  ['brain', 6.204106435680452e-05, 6.66548279924568e-05, 0, 'Italian'],
#  ['of', 0.09166666666666666, 0.028268551236749116, 1, 'English'],
#  ['how', 0.002791878172588833, 0, 1, 'English'],
#  ['are', 0.04178584753140156, 0.06433149171270719, 0, 'Italian'],
#  ['you', 0.21355555555555558, 0, 1, 'English'],
#  ['or', 0.125, 0.19434628975265017, 0, 'Italian'],
#  ['quality', 9.253880422810831e-07, 0.0, 1, 'English'],
#  ['as', 0.055232558139534885, 0.050666666666666665, 1, 'English'],
#  ['listening', 1.3694218393818707e-07, 1.1842965076783117e-08, 1, 'English'],
#  ['can', 0.052451971688574316, 0.020707964601769914, 1, 'English'],
#  ['be', 0.26865671641791045, 0.13636363636363635, 1, 'English'],
#  ['insurance', 1.7688038213418115e-08, 1.6647803949872526e-09, 1, 'English'],
#  ['snacks', 0.0, 0.0, 1, 'English'],
#  ['an', 0.24127906976744187, 0.17333333333333334, 1, 'English'],
#  ['colors', 4.325657094347988e-06, 1.21756522780038e-05, 0, 'Italian'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['enjoy', 0.0, 0.0, 1, 'English'],
#  ['will', 0.0045994119874326255, 0.014198237666152237, 0, 'Italian'],
#  ['can', 0.052451971688574316, 0.020707964601769914, 1, 'English'],
#  ['irritate', 2.8908724206823603e-09, 3.132953803120823e-08, 0, 'Italian'],
#  ['there', 0.010223048717441527, 0.0, 1, 'English'],
#  ['floor', 3.938992878300876e-05, 0.0, 1, 'English'],
#  ['for', 0.027439024390243903, 0.024916190993929506, 1, 'English'],
#  ['and', 0.0457598235765838, 0.01855249745158002, 1, 'English'],
#  ['from', 0.00028694404591104734, 0.00023464519394082286, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['from', 0.00028694404591104734, 0.00023464519394082286, 1, 'English'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['away', 7.846905663292899e-05, 0, 1, 'English'],
#  ['by', 0.08955223880597014, 0, 1, 'English'],
#  ['crisis', 1.59065466562363e-06, 6.631475189256543e-07, 1, 'English'],
#  ['your', 0.06438071895424836, 0.0, 1, 'English'],
#  ['inspire', 2.3794227586191965e-06, 4.3537937283027183e-07, 1, 'English'],
#  ['before', 1.226422991343011e-05, 6.431500580439267e-06, 1, 'English'],
#  ['felt', 9.453582907922101e-05, 0.0008233913211050962, 0, 'Italian'],
#  ['children', 4.245265978196498e-07, 0.0, 1, 'English'],
#  ['leads', 4.9211815607800726e-05, 0.0, 1, 'English'],
#  ['milestones', 1.5508323249343947e-08, 1.500176734835603e-08, 1, 'English'],
#  ['them', 0.005251950852092213, 0.0, 1, 'English'],
#  ['plastic', 1.428347079677065e-06, 1.5412118670644252e-06, 0, 'Italian'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['party', 4.9236945028205566e-05, 0.0, 1, 'English'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['the', 0.18907023067531967, 0.0, 1, 'English'],
#  ['top', 0.0028832630098452883, 0.00465396880117211, 0, 'Italian'],
#  ['television', 4.5802061216846335e-10, 7.80090510820712e-09, 0, 'Italian'],
#  ['happiness', 1.9793277759428595e-09, 5.753861377395709e-09, 0, 'Italian'],
#  ['so', 0.1286549707602339, 0.13360323886639677, 0, 'Italian'],
#  ['sewing', 5.540378276881915e-05, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['with', 0.009949303774856302, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['meditation', 2.3332921550354237e-09, 1.7144063933752066e-08, 0, 'Italian'],
#  ['thin', 0.012937251412317904, 0.0, 1, 'English'],
#  ['love', 0.00210222047037183, 0.0008190546036402427, 1, 'English'],
#  ['whose', 7.515498654513704e-05, 0.0, 1, 'English'],
#  ['cars', 0.002595394256608793, 0.00043739304747469806, 1, 'English'],
#  ['to', 0.12974683544303797, 0.14634146341463414, 0, 'Italian'],
#  ['friendship', 6.686481860736931e-11, 0.0, 1, 'English'],
#  ['doors', 6.116528607878088e-05, 2.0375838121137907e-06, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['do', 0.10294117647058823, 0.15343915343915343, 0, 'Italian'],
#  ['vary', 0.000822058138480963, 0.0, 1, 'English'],
#  ['negotiations',
#   1.2940483835858604e-14,
#   1.3842191195405832e-12,
#   0,
#   'Italian'],
#  ['or', 0.125, 0.19434628975265017, 0, 'Italian'],
#  ['cross', 2.6513621883119794e-06, 2.1683095704638684e-05, 0, 'Italian'],
#  ['blind', 0.0005762738765194646, 6.5419484181813e-05, 1, 'English']]

# %%
# create a dataframe from the resulting list
df_bigram_res = pd.DataFrame(bigram_res,columns = ['word','en_prob','it_prob','english','language prediction'])

df_bigram_res.head(20)
# Out:
#         word       en_prob   it_prob  english language prediction
# 0          a  1.000000e+00  1.000000        1             English
# 1        for  2.743902e-02  0.024916        1             English
# 2         of  9.166667e-02  0.028269        1             English
# 3       your  6.438072e-02  0.000000        1             English
# 4          a  1.000000e+00  1.000000        1             English
# 5     street  4.740769e-06  0.000001        1             English
# 6     easier  3.798859e-06  0.000001        1             English
# 7       help  1.263133e-03  0.000759        1             English
# 8   physical  3.074526e-10  0.000000        1             English
# 9   thoughts  2.241879e-08  0.000000        1             English
# 10        is  1.028939e-01  0.039578        1             English
# 11        on  1.194444e-01  0.268551        0             Italian
# 12     areas  2.115611e-04  0.000073        1             English
# 13       for  2.743902e-02  0.024916        1             English
# 14      down  8.169935e-05  0.000000        1             English
# 15        to  1.297468e-01  0.146341        0             Italian
# 16  websites  0.000000e+00  0.000000        1             English
# 17    pizzas  5.064142e-06  0.000006        0             Italian
# 18     other  1.706884e-03  0.000000        1             English
# 19   travels  1.274095e-07  0.000000        1             English

# %%
# count the number of words classified as an english word
bigram_eng_pos = df_bigram_res.english.sum()

# count the number of words in the df
bigram_total_words = len(df_bigram_res.index)

# calculate the accuracy of the bigram model
bigram_accuracy = bigram_eng_pos/bigram_total_words

bigram_accuracy
# Out:
# 0.7338403041825095

# %% [markdown]
# #### ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Trigram Model

# %%
# Create an empty dictionary inside of a dictionary
en_model_3 = defaultdict(lambda: defaultdict(lambda: 0))

# loop through the words in the english training list of words 
for words in train_en:
    
    # using the ngrams package loop through the trigrams and create a dictionary of counts for each trigram  
    for let1, let2, let3 in ngrams(words, 3):
        en_model_3[(let1,let2)][let3] += 1


# transform the counts to probabilities
#loop through each key letter in the bigram model
for let1_let2 in en_model_3:
    
    # creates a total count of the values under the key letters
    total_count = float(sum(en_model_3[let1_let2].values()))
    
    # loops through the second letters of the bigrams for each first letter
    for let3 in en_model_3[let1_let2]:
        
        # divides the third letter count by the total count of the first two letter key in the trigram
        en_model_3[let1_let2][let3] /= total_count
        
        
en_model_3
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('e',
#               'x'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.5714285714285714,
#                           'i': 0.14285714285714285,
#                           'a': 0.14285714285714285,
#                           't': 0.14285714285714285}),
#              ('x',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.25,
#                           'e': 0.75}),
#              ('p',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.16666666666666666,
#                           't': 0.05555555555555555,
#                           'r': 0.3888888888888889,
#                           's': 0.1111111111111111,
#                           'c': 0.16666666666666666,
#                           'p': 0.05555555555555555,
#                           'i': 0.05555555555555555}),
#              ('a',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.5483870967741935,
#                           'n': 0.04838709677419355,
#                           'y': 0.14516129032258066,
#                           'c': 0.016129032258064516,
#                           's': 0.06451612903225806,
#                           'i': 0.016129032258064516,
#                           't': 0.12903225806451613,
#                           'g': 0.03225806451612903}),
#              ('a',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.6666666666666666,
#                           'l': 0.16666666666666666,
#                           'b': 0.16666666666666666}),
#              ('b',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.25,
#                           'o': 0.25,
#                           'n': 0.1875,
#                           'b': 0.0625,
#                           'd': 0.1875,
#                           't': 0.0625}),
#              ('o',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.11864406779661017,
#                           'r': 0.5084745762711864,
#                           'l': 0.11864406779661017,
#                           's': 0.0847457627118644,
#                           'b': 0.03389830508474576,
#                           'f': 0.01694915254237288,
#                           'g': 0.05084745762711865,
#                           'n': 0.05084745762711865,
#                           'c': 0.01694915254237288}),
#              ('h',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.21212121212121213,
#                           'p': 0.09090909090909091,
#                           'v': 0.21212121212121213,
#                           't': 0.21212121212121213,
#                           's': 0.12121212121212122,
#                           'r': 0.06060606060606061,
#                           'd': 0.030303030303030304,
#                           'i': 0.030303030303030304,
#                           'l': 0.030303030303030304}),
#              ('t',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.8041237113402062,
#                           'a': 0.09278350515463918,
#                           'l': 0.010309278350515464,
#                           'o': 0.010309278350515464,
#                           'r': 0.041237113402061855,
#                           'i': 0.030927835051546393,
#                           's': 0.010309278350515464}),
#              ('a',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.037037037037037035,
#                           'e': 0.5185185185185185,
#                           'i': 0.18518518518518517,
#                           'c': 0.07407407407407407,
#                           'h': 0.07407407407407407,
#                           't': 0.1111111111111111}),
#              ('t',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('m',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.14285714285714285,
#                           'u': 0.07142857142857142,
#                           'n': 0.14285714285714285,
#                           'v': 0.14285714285714285,
#                           'r': 0.35714285714285715,
#                           't': 0.07142857142857142,
#                           'i': 0.07142857142857142}),
#              ('o',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.16666666666666666,
#                           't': 0.3333333333333333,
#                           'e': 0.3333333333333333,
#                           's': 0.16666666666666666}),
#              ('s',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 0.08333333333333333,
#                           'o': 0.25,
#                           'e': 0.25,
#                           'y': 0.08333333333333333,
#                           'a': 0.16666666666666666,
#                           'l': 0.08333333333333333,
#                           'i': 0.08333333333333333}),
#              ('p',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'o': 0.6666666666666666}),
#              ('h',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.24,
#                           'i': 0.1,
#                           'd': 0.04,
#                           'l': 0.12,
#                           'a': 0.12,
#                           'y': 0.1,
#                           'n': 0.18,
#                           'm': 0.06,
#                           's': 0.04}),
#              ('e',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.22857142857142856,
#                           'a': 0.05714285714285714,
#                           'y': 0.11428571428571428,
#                           'i': 0.08571428571428572,
#                           'w': 0.02857142857142857,
#                           's': 0.2857142857142857,
#                           'v': 0.08571428571428572,
#                           'c': 0.05714285714285714,
#                           't': 0.02857142857142857,
#                           'g': 0.02857142857142857}),
#              ('a',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.5,
#                           'e': 0.5}),
#              ('p',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('p',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.1111111111111111,
#                           'n': 0.5555555555555556,
#                           'c': 0.1111111111111111,
#                           'r': 0.1111111111111111,
#                           'z': 0.1111111111111111}),
#              ('i',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.13333333333333333,
#                           'l': 0.2,
#                           's': 0.2,
#                           'v': 0.2,
#                           'n': 0.2,
#                           'w': 0.06666666666666667}),
#              ('c',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.36666666666666664,
#                           'l': 0.1,
#                           't': 0.16666666666666666,
#                           'r': 0.3,
#                           'd': 0.03333333333333333,
#                           'u': 0.03333333333333333}),
#              ('p',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.6666666666666666,
#                           'e': 0.16666666666666666,
#                           'i': 0.16666666666666666}),
#              ('r',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'f': 0.1111111111111111,
#                           'c': 0.05555555555555555,
#                           's': 0.1111111111111111,
#                           'u': 0.2222222222222222,
#                           'w': 0.1111111111111111,
#                           'y': 0.16666666666666666,
#                           'n': 0.05555555555555555,
#                           'd': 0.05555555555555555,
#                           'v': 0.05555555555555555,
#                           'm': 0.05555555555555555}),
#              ('o',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2,
#                           'f': 0.6,
#                           't': 0.2}),
#              ('f',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.125,
#                           'r': 0.0625,
#                           'n': 0.125,
#                           'e': 0.25,
#                           'l': 0.0625,
#                           'c': 0.0625,
#                           'a': 0.0625,
#                           'w': 0.1875,
#                           't': 0.0625}),
#              ('e',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.3181818181818182,
#                           't': 0.5,
#                           'e': 0.045454545454545456,
#                           'o': 0.045454545454545456,
#                           'p': 0.09090909090909091}),
#              ('s',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5714285714285714,
#                           'y': 0.14285714285714285,
#                           'a': 0.14285714285714285,
#                           'e': 0.14285714285714285}),
#              ('s',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.46153846153846156,
#                           'n': 0.23076923076923078,
#                           'z': 0.07692307692307693,
#                           'd': 0.07692307692307693,
#                           'l': 0.07692307692307693,
#                           'c': 0.07692307692307693}),
#              ('i',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.8666666666666667,
#                           'u': 0.13333333333333333}),
#              ('o',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.14285714285714285,
#                           'e': 0.14285714285714285,
#                           's': 0.23809523809523808,
#                           'o': 0.14285714285714285,
#                           'g': 0.14285714285714285,
#                           't': 0.09523809523809523,
#                           'm': 0.047619047619047616,
#                           'y': 0.047619047619047616}),
#              ('n',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 1.0}),
#              ('p',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.19047619047619047,
#                           'd': 0.047619047619047616,
#                           'r': 0.38095238095238093,
#                           'n': 0.09523809523809523,
#                           'c': 0.09523809523809523,
#                           's': 0.09523809523809523,
#                           'a': 0.047619047619047616,
#                           't': 0.047619047619047616}),
#              ('e',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.8,
#                           'n': 0.2}),
#              ('o',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.5714285714285714,
#                           'e': 0.2857142857142857,
#                           'p': 0.14285714285714285}),
#              ('p',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.4444444444444444,
#                           'a': 0.5555555555555556}),
#              ('d',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.23809523809523808,
#                           'a': 0.047619047619047616,
#                           'm': 0.047619047619047616,
#                           'n': 0.19047619047619047,
#                           'p': 0.047619047619047616,
#                           's': 0.14285714285714285,
#                           'r': 0.09523809523809523,
#                           'l': 0.047619047619047616,
#                           'd': 0.047619047619047616,
#                           'e': 0.047619047619047616,
#                           'v': 0.047619047619047616}),
#              ('e',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.35714285714285715,
#                           'u': 0.14285714285714285,
#                           't': 0.21428571428571427,
#                           'k': 0.07142857142857142,
#                           'i': 0.14285714285714285,
#                           'a': 0.07142857142857142}),
#              ('c',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.07407407407407407,
#                           'u': 0.18518518518518517,
#                           'o': 0.18518518518518517,
#                           'n': 0.1111111111111111,
#                           'm': 0.37037037037037035,
#                           'f': 0.037037037037037035,
#                           'l': 0.037037037037037035}),
#              ('o',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.10526315789473684,
#                           'k': 0.10526315789473684,
#                           'y': 0.10526315789473684,
#                           'e': 0.3157894736842105,
#                           's': 0.05263157894736842,
#                           'm': 0.10526315789473684,
#                           't': 0.10526315789473684,
#                           'l': 0.05263157894736842,
#                           'n': 0.05263157894736842}),
#              ('r',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.21428571428571427,
#                           'c': 0.14285714285714285,
#                           'i': 0.2857142857142857,
#                           's': 0.14285714285714285,
#                           'v': 0.07142857142857142,
#                           'l': 0.07142857142857142,
#                           'b': 0.07142857142857142}),
#              ('s',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.2631578947368421,
#                           'i': 0.05263157894736842,
#                           'g': 0.10526315789473684,
#                           'r': 0.10526315789473684,
#                           'u': 0.10526315789473684,
#                           'o': 0.10526315789473684,
#                           'n': 0.15789473684210525,
#                           'v': 0.05263157894736842,
#                           'f': 0.05263157894736842}),
#              ('o',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.55,
#                           'p': 0.2,
#                           'a': 0.05,
#                           's': 0.05,
#                           'b': 0.05,
#                           'f': 0.05,
#                           'i': 0.05}),
#              ('m',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.043478260869565216,
#                           'd': 0.13043478260869565,
#                           'n': 0.391304347826087,
#                           's': 0.2608695652173913,
#                           't': 0.043478260869565216,
#                           'a': 0.043478260869565216,
#                           'w': 0.043478260869565216,
#                           'r': 0.043478260869565216}),
#              ('i',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.09090909090909091,
#                           'g': 0.4935064935064935,
#                           'c': 0.012987012987012988,
#                           'i': 0.03896103896103896,
#                           'u': 0.05194805194805195,
#                           'v': 0.05194805194805195,
#                           'd': 0.03896103896103896,
#                           's': 0.06493506493506493,
#                           'k': 0.03896103896103896,
#                           'f': 0.012987012987012988,
#                           'e': 0.09090909090909091,
#                           'n': 0.012987012987012988}),
#              ('n',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2962962962962963,
#                           'i': 0.3333333333333333,
#                           'h': 0.037037037037037035,
#                           's': 0.18518518518518517,
#                           'a': 0.07407407407407407,
#                           'u': 0.037037037037037035,
#                           'l': 0.037037037037037035}),
#              ('t',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.4594594594594595,
#                           'm': 0.02702702702702703,
#                           's': 0.10810810810810811,
#                           'd': 0.08108108108108109,
#                           'n': 0.1891891891891892,
#                           'l': 0.05405405405405406,
#                           'g': 0.02702702702702703,
#                           'a': 0.02702702702702703,
#                           'x': 0.02702702702702703}),
#              ('a',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.32,
#                           'e': 0.36,
#                           'a': 0.04,
#                           'h': 0.24,
#                           'r': 0.04}),
#              ('c',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.875,
#                           'u': 0.125}),
#              ('t',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.16129032258064516,
#                           'l': 0.16129032258064516,
#                           'o': 0.1935483870967742,
#                           'v': 0.16129032258064516,
#                           'm': 0.12903225806451613,
#                           'c': 0.03225806451612903,
#                           't': 0.06451612903225806,
#                           'a': 0.06451612903225806,
#                           'r': 0.03225806451612903}),
#              ('u',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.36363636363636365,
#                           'g': 0.18181818181818182,
#                           'n': 0.18181818181818182,
#                           'd': 0.18181818181818182,
#                           'h': 0.09090909090909091}),
#              ('h',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.2,
#                           'u': 0.25,
#                           'l': 0.15,
#                           'w': 0.1,
#                           's': 0.05,
#                           'm': 0.15,
#                           't': 0.05,
#                           'p': 0.05}),
#              ('n',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.2857142857142857,
#                           'r': 0.23809523809523808,
#                           'g': 0.047619047619047616,
#                           'w': 0.047619047619047616,
#                           'e': 0.19047619047619047,
#                           'y': 0.047619047619047616,
#                           'd': 0.09523809523809523,
#                           'v': 0.047619047619047616}),
#              ('s',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 0.037037037037037035,
#                           'a': 0.3333333333333333,
#                           'o': 0.14814814814814814,
#                           'r': 0.18518518518518517,
#                           'u': 0.1111111111111111,
#                           'e': 0.1111111111111111,
#                           'i': 0.07407407407407407}),
#              ('y',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0}),
#              ('n',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.3333333333333333,
#                           'r': 0.2222222222222222,
#                           'b': 0.1111111111111111,
#                           'u': 0.1111111111111111,
#                           'x': 0.1111111111111111,
#                           'v': 0.1111111111111111}),
#              ('t',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.2631578947368421,
#                           't': 0.21052631578947367,
#                           'k': 0.15789473684210525,
#                           'c': 0.05263157894736842,
#                           'i': 0.05263157894736842,
#                           'b': 0.05263157894736842,
#                           'n': 0.10526315789473684,
#                           'r': 0.05263157894736842,
#                           'y': 0.05263157894736842}),
#              ('a',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'k': 0.18181818181818182,
#                           'l': 0.45454545454545453,
#                           'a': 0.045454545454545456,
#                           't': 0.045454545454545456,
#                           's': 0.09090909090909091,
#                           'i': 0.09090909090909091,
#                           'e': 0.045454545454545456,
#                           'f': 0.045454545454545456}),
#              ('m',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.3333333333333333,
#                           'l': 0.09523809523809523,
#                           'k': 0.14285714285714285,
#                           't': 0.14285714285714285,
#                           'i': 0.047619047619047616,
#                           'g': 0.19047619047619047,
#                           'c': 0.047619047619047616}),
#              ('n',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'y': 0.16666666666666666,
#                           'u': 0.16666666666666666,
#                           'i': 0.3333333333333333}),
#              ('e',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.75,
#                           'l': 0.25}),
#              ('d',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.07142857142857142,
#                           'o': 0.07142857142857142,
#                           'g': 0.07142857142857142,
#                           'n': 0.2857142857142857,
#                           's': 0.2857142857142857,
#                           'e': 0.07142857142857142,
#                           'u': 0.07142857142857142,
#                           'a': 0.07142857142857142}),
#              ('i',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.23076923076923078,
#                           'k': 0.23076923076923078,
#                           'e': 0.38461538461538464,
#                           'h': 0.15384615384615385}),
#              ('f',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 1.0}),
#              ('c',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'b': 0.2,
#                           'r': 0.2,
#                           's': 0.6}),
#              ('e',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('o',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'k': 0.5882352941176471,
#                           'r': 0.058823529411764705,
#                           'd': 0.17647058823529413,
#                           't': 0.17647058823529413}),
#              ('l',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'w': 0.09090909090909091,
#                           'c': 0.18181818181818182,
#                           'n': 0.09090909090909091,
#                           's': 0.045454545454545456,
#                           'y': 0.22727272727272727,
#                           'r': 0.13636363636363635,
#                           'd': 0.045454545454545456,
#                           'g': 0.045454545454545456,
#                           't': 0.045454545454545456,
#                           'x': 0.045454545454545456,
#                           'i': 0.045454545454545456}),
#              ('a',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.4,
#                           'a': 0.6}),
#              ('w',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0}),
#              ('s',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.375,
#                           'f': 0.375,
#                           'g': 0.125,
#                           'r': 0.125}),
#              ('u',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.5,
#                           'c': 0.25,
#                           'n': 0.25}),
#              ('n',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2,
#                           'e': 0.6,
#                           'y': 0.2}),
#              ('c',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'o': 0.3333333333333333,
#                           'i': 0.3333333333333333}),
#              ('r',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.25,
#                           'e': 0.041666666666666664,
#                           's': 0.25,
#                           'd': 0.041666666666666664,
#                           'l': 0.125,
#                           'n': 0.125,
#                           'g': 0.041666666666666664,
#                           'p': 0.041666666666666664,
#                           'i': 0.041666666666666664,
#                           'c': 0.041666666666666664}),
#              ('e',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.12121212121212122,
#                           'l': 0.09090909090909091,
#                           't': 0.12121212121212122,
#                           'd': 0.18181818181818182,
#                           'r': 0.21212121212121213,
#                           'n': 0.06060606060606061,
#                           'k': 0.09090909090909091,
#                           'c': 0.06060606060606061,
#                           'f': 0.030303030303030304,
#                           'm': 0.030303030303030304}),
#              ('a',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.18181818181818182,
#                           's': 0.18181818181818182,
#                           'a': 0.09090909090909091,
#                           'e': 0.2727272727272727,
#                           'h': 0.09090909090909091,
#                           't': 0.18181818181818182}),
#              ('n',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.16666666666666666,
#                           'i': 0.16666666666666666,
#                           's': 0.16666666666666666,
#                           'u': 0.16666666666666666,
#                           'r': 0.16666666666666666,
#                           'e': 0.16666666666666666}),
#              ('g',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1.0}),
#              ('s',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.1875,
#                           'a': 0.125,
#                           'e': 0.0625,
#                           's': 0.1875,
#                           'c': 0.125,
#                           'l': 0.0625,
#                           'd': 0.0625,
#                           't': 0.0625,
#                           'r': 0.0625,
#                           'v': 0.0625}),
#              ('e',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.15151515151515152,
#                           't': 0.5151515151515151,
#                           'c': 0.09090909090909091,
#                           's': 0.12121212121212122,
#                           'v': 0.030303030303030304,
#                           'o': 0.030303030303030304,
#                           'e': 0.030303030303030304,
#                           'i': 0.030303030303030304}),
#              ('i',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.8333333333333334,
#                           'i': 0.16666666666666666}),
#              ('l',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 0.2727272727272727,
#                           's': 0.09090909090909091,
#                           'e': 0.2727272727272727,
#                           'u': 0.18181818181818182,
#                           'a': 0.09090909090909091,
#                           'o': 0.09090909090909091}),
#              ('o',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.16666666666666666,
#                           'r': 0.16666666666666666,
#                           'c': 0.16666666666666666,
#                           'n': 0.3333333333333333,
#                           's': 0.16666666666666666}),
#              ('a',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.9090909090909091,
#                           'i': 0.09090909090909091}),
#              ('w',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.4,
#                           'l': 0.35,
#                           's': 0.1,
#                           'n': 0.15}),
#              ('i',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 0.42105263157894735,
#                           'y': 0.21052631578947367,
#                           'e': 0.10526315789473684,
#                           'a': 0.05263157894736842,
#                           's': 0.10526315789473684,
#                           'c': 0.05263157894736842,
#                           't': 0.05263157894736842}),
#              ('u',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.7777777777777778,
#                           'y': 0.1111111111111111,
#                           'e': 0.1111111111111111}),
#              ('e',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.8571428571428571,
#                           'i': 0.14285714285714285}),
#              ('w',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.6,
#                           'm': 0.4}),
#              ('h',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.08695652173913043,
#                           'l': 0.21739130434782608,
#                           'e': 0.08695652173913043,
#                           'n': 0.34782608695652173,
#                           'o': 0.043478260869565216,
#                           'g': 0.043478260869565216,
#                           'c': 0.08695652173913043,
#                           'p': 0.043478260869565216,
#                           'd': 0.043478260869565216}),
#              ('i',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.36363636363636365,
#                           'h': 0.18181818181818182,
#                           'e': 0.09090909090909091,
#                           'm': 0.045454545454545456,
#                           's': 0.13636363636363635,
#                           'p': 0.09090909090909091,
#                           'i': 0.09090909090909091}),
#              ('t',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2727272727272727,
#                           'o': 0.2727272727272727,
#                           'm': 0.09090909090909091,
#                           'i': 0.09090909090909091,
#                           'n': 0.09090909090909091,
#                           'd': 0.09090909090909091,
#                           'u': 0.09090909090909091}),
#              ('e',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.8333333333333334,
#                           'g': 0.16666666666666666}),
#              ('f',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.6666666666666666,
#                           't': 0.3333333333333333}),
#              ('o',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5,
#                           'i': 0.16666666666666666,
#                           's': 0.3333333333333333}),
#              ('k',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.25,
#                           'r': 0.5,
#                           's': 0.25}),
#              ('l',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.0625,
#                           'w': 0.25,
#                           'n': 0.125,
#                           'a': 0.1875,
#                           'v': 0.125,
#                           'o': 0.0625,
#                           'c': 0.125,
#                           'p': 0.0625}),
#              ('w',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'v': 0.07692307692307693,
#                           't': 0.23076923076923078,
#                           'y': 0.23076923076923078,
#                           'l': 0.07692307692307693,
#                           'n': 0.23076923076923078,
#                           'r': 0.15384615384615385}),
#              ('v',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.2222222222222222,
#                           'n': 0.18518518518518517,
#                           'l': 0.1111111111111111,
#                           'm': 0.1111111111111111,
#                           'd': 0.07407407407407407,
#                           'r': 0.2962962962962963}),
#              ('i',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.6,
#                           'd': 0.2,
#                           'e': 0.1,
#                           'y': 0.05,
#                           's': 0.05}),
#              ('d',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.3333333333333333,
#                           'u': 0.3333333333333333,
#                           'i': 0.3333333333333333}),
#              ('b',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.3333333333333333,
#                           'f': 0.08333333333333333,
#                           'd': 0.16666666666666666,
#                           'c': 0.25,
#                           'h': 0.08333333333333333,
#                           's': 0.08333333333333333}),
#              ('e',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.45454545454545453,
#                           'h': 0.09090909090909091,
#                           'e': 0.18181818181818182,
#                           's': 0.09090909090909091,
#                           'r': 0.09090909090909091,
#                           'y': 0.09090909090909091}),
#              ('t',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5,
#                           'a': 0.1,
#                           'l': 0.2,
#                           'i': 0.1,
#                           'o': 0.1}),
#              ('t',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.3125,
#                           'y': 0.25,
#                           'e': 0.0625,
#                           'o': 0.25,
#                           'u': 0.125}),
#              ('a',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.08333333333333333,
#                           'r': 0.3333333333333333,
#                           'l': 0.08333333333333333,
#                           'n': 0.3333333333333333,
#                           'd': 0.08333333333333333,
#                           'm': 0.08333333333333333}),
#              ('i',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 0.6666666666666666,
#                           'e': 0.16666666666666666,
#                           'n': 0.16666666666666666}),
#              ('g',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.75,
#                           'e': 0.25}),
#              ('f',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6,
#                           'o': 0.2,
#                           'é': 0.2}),
#              ('l',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.09090909090909091,
#                           'f': 0.18181818181818182,
#                           's': 0.13636363636363635,
#                           'r': 0.09090909090909091,
#                           'k': 0.09090909090909091,
#                           'd': 0.045454545454545456,
#                           'm': 0.045454545454545456,
#                           'p': 0.045454545454545456,
#                           'n': 0.09090909090909091,
#                           'g': 0.045454545454545456,
#                           'e': 0.045454545454545456,
#                           'z': 0.045454545454545456,
#                           't': 0.045454545454545456}),
#              ('a',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3023255813953488,
#                           'k': 0.023255813953488372,
#                           'b': 0.06976744186046512,
#                           'd': 0.16279069767441862,
#                           'c': 0.023255813953488372,
#                           't': 0.16279069767441862,
#                           'i': 0.06976744186046512,
#                           'n': 0.023255813953488372,
#                           'g': 0.09302325581395349,
#                           'y': 0.023255813953488372,
#                           'o': 0.023255813953488372,
#                           'm': 0.023255813953488372}),
#              ('s',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.42857142857142855,
#                           'e': 0.21428571428571427,
#                           'i': 0.14285714285714285,
#                           'a': 0.14285714285714285,
#                           'y': 0.07142857142857142}),
#              ('g',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.5,
#                           't': 0.1,
#                           'r': 0.3,
#                           'l': 0.1}),
#              ('a',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.75,
#                           'p': 0.125,
#                           'a': 0.125}),
#              ('f',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.2727272727272727,
#                           'e': 0.2727272727272727,
#                           'c': 0.2727272727272727,
#                           'l': 0.09090909090909091,
#                           't': 0.09090909090909091}),
#              ('n',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.2857142857142857,
#                           'm': 0.14285714285714285,
#                           'n': 0.5714285714285714}),
#              ('p',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.18181818181818182,
#                           'p': 0.09090909090909091,
#                           'u': 0.18181818181818182,
#                           'l': 0.18181818181818182,
#                           'n': 0.18181818181818182,
#                           'r': 0.09090909090909091,
#                           'e': 0.09090909090909091}),
#              ('o',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.06666666666666667,
#                           'e': 0.13333333333333333,
#                           'h': 0.6,
#                           'i': 0.06666666666666667,
#                           'o': 0.06666666666666667,
#                           'p': 0.06666666666666667}),
#              ('a',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.7272727272727273,
#                           'i': 0.2727272727272727}),
#              ('e',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.3,
#                           'd': 0.15,
#                           'e': 0.1,
#                           'f': 0.05,
#                           'l': 0.1,
#                           'y': 0.1,
#                           'i': 0.05,
#                           'a': 0.1,
#                           'o': 0.05}),
#              ('i',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('b',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.3333333333333333,
#                           'n': 0.3333333333333333,
#                           's': 0.3333333333333333}),
#              ('o',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'i': 0.25,
#                           'o': 0.08333333333333333}),
#              ('s',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.5,
#                           'i': 0.25,
#                           'e': 0.25}),
#              ('i',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5,
#                           'a': 0.25,
#                           'z': 0.25}),
#              ('p',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'b': 0.2857142857142857,
#                           't': 0.42857142857142855,
#                           'f': 0.14285714285714285,
#                           'r': 0.14285714285714285}),
#              ('u',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.75,
#                           't': 0.25}),
#              ('b',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.4,
#                           'e': 0.4,
#                           'a': 0.2}),
#              ('t',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.125,
#                           'r': 0.75,
#                           'a': 0.125}),
#              ('u',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'k': 0.16666666666666666,
#                           'h': 0.6666666666666666,
#                           'i': 0.16666666666666666}),
#              ('u',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.26666666666666666,
#                           'h': 0.13333333333333333,
#                           'i': 0.2,
#                           't': 0.4}),
#              ('g',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'o': 0.3333333333333333,
#                           'y': 0.16666666666666666}),
#              ('m',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.07692307692307693,
#                           'c': 0.07692307692307693,
#                           'n': 0.38461538461538464,
#                           't': 0.07692307692307693,
#                           's': 0.3076923076923077,
#                           'l': 0.07692307692307693}),
#              ('v',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.25,
#                           'l': 0.25,
#                           'i': 0.25,
#                           'k': 0.25}),
#              ('s',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.6666666666666666,
#                           'i': 0.3333333333333333}),
#              ('l',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.10526315789473684,
#                           'd': 0.10526315789473684,
#                           'a': 0.3157894736842105,
#                           'g': 0.05263157894736842,
#                           'm': 0.05263157894736842,
#                           't': 0.10526315789473684,
#                           'n': 0.05263157894736842,
#                           'r': 0.10526315789473684,
#                           'f': 0.05263157894736842,
#                           'e': 0.05263157894736842}),
#              ('b',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.2857142857142857,
#                           's': 0.14285714285714285,
#                           'k': 0.42857142857142855,
#                           't': 0.14285714285714285}),
#              ('u',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.15384615384615385,
#                           's': 0.23076923076923078,
#                           'e': 0.38461538461538464,
#                           't': 0.07692307692307693,
#                           'b': 0.07692307692307693,
#                           'i': 0.07692307692307693}),
#              ('o',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('i',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.7142857142857143,
#                           'a': 0.2857142857142857}),
#              ('i',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'a': 0.3333333333333333,
#                           'i': 0.08333333333333333,
#                           'p': 0.16666666666666666,
#                           'm': 0.08333333333333333}),
#              ('g',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.5,
#                           'l': 0.5}),
#              ('r',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.75,
#                           'e': 0.25}),
#              ('n',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.16666666666666666,
#                           'e': 0.16666666666666666,
#                           't': 0.5,
#                           'a': 0.16666666666666666}),
#              ('r',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2857142857142857,
#                           'p': 0.14285714285714285,
#                           'o': 0.42857142857142855,
#                           'u': 0.14285714285714285}),
#              ('e',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.09090909090909091,
#                           'd': 0.36363636363636365,
#                           'l': 0.2727272727272727,
#                           'p': 0.18181818181818182,
#                           'v': 0.09090909090909091}),
#              ('u',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'f': 1.0}),
#              ('f',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.4166666666666667,
#                           'o': 0.16666666666666666,
#                           'l': 0.08333333333333333,
# ...
#                           's': 0.5}),
#              ('c',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.7692307692307693,
#                           'a': 0.23076923076923078}),
#              ('e',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.9090909090909091,
#                           'i': 0.09090909090909091}),
#              ('f',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.16666666666666666,
#                           'r': 0.6666666666666666,
#                           'c': 0.16666666666666666}),
#              ('o',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.2857142857142857,
#                           'y': 0.42857142857142855,
#                           'u': 0.14285714285714285,
#                           'i': 0.14285714285714285}),
#              ('o',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.375,
#                           'v': 0.125,
#                           'l': 0.375,
#                           'e': 0.125}),
#              ('l',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.3333333333333333,
#                           'r': 0.3333333333333333,
#                           'e': 0.3333333333333333}),
#              ('r',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 0.3333333333333333,
#                           'l': 0.3333333333333333,
#                           'o': 0.3333333333333333}),
#              ('n',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6,
#                           'o': 0.2,
#                           'e': 0.2}),
#              ('r',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.14285714285714285,
#                           'h': 0.2857142857142857,
#                           'n': 0.14285714285714285,
#                           'a': 0.2857142857142857,
#                           'o': 0.14285714285714285}),
#              ('r',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('l',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 1.0}),
#              ('e',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.5,
#                           't': 0.5}),
#              ('c',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.4,
#                           'e': 0.2,
#                           'o': 0.4}),
#              ('u',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'i': 0.1111111111111111,
#                           't': 0.1111111111111111,
#                           'u': 0.1111111111111111}),
#              ('w',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.25,
#                           'r': 0.25,
#                           'l': 0.25,
#                           'e': 0.25}),
#              ('s',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.14285714285714285,
#                           'n': 0.14285714285714285,
#                           'v': 0.2857142857142857,
#                           'f': 0.2857142857142857,
#                           'm': 0.14285714285714285}),
#              ('a',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'i': 0.3333333333333333}),
#              ('m',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1.0}),
#              ('y',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 1.0}),
#              ('c',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2,
#                           't': 0.2,
#                           's': 0.4,
#                           'd': 0.2}),
#              ('n',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.36363636363636365,
#                           'o': 0.18181818181818182,
#                           'i': 0.09090909090909091,
#                           'u': 0.09090909090909091,
#                           'p': 0.09090909090909091,
#                           'h': 0.09090909090909091,
#                           't': 0.09090909090909091}),
#              ('i',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('w',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'i': 0.13333333333333333,
#                           'o': 0.2}),
#              ('l',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('b',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6,
#                           'o': 0.2,
#                           'i': 0.2}),
#              ('t',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 1.0}),
#              ('o',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2,
#                           'n': 0.4,
#                           'i': 0.2,
#                           't': 0.2}),
#              ('o',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'b': 0.5,
#                           'o': 0.5}),
#              ('b',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 0.5,
#                           'i': 0.5}),
#              ('r',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5,
#                           't': 0.5}),
#              ('y',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('a',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.4,
#                           's': 0.2,
#                           'e': 0.4}),
#              ('m',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.2857142857142857,
#                           'a': 0.2857142857142857,
#                           'l': 0.2857142857142857,
#                           'o': 0.14285714285714285}),
#              ('m',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.5,
#                           's': 0.5}),
#              ('r',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.4,
#                           'g': 0.2,
#                           's': 0.2,
#                           'n': 0.2}),
#              ('f',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('e',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.5,
#                           'e': 0.5}),
#              ('r',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('t',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('a',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1.0}),
#              ('u',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.2,
#                           'h': 0.6,
#                           'b': 0.2}),
#              ('e',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('i',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1.0}),
#              ('n',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('r',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('l',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('b',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.25,
#                           'n': 0.5,
#                           't': 0.25}),
#              ('t',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5,
#                           'y': 0.5}),
#              ('y',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.5,
#                           'd': 0.5}),
#              ('h',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.5,
#                           'e': 0.25,
#                           'i': 0.25}),
#              ('u',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 1.0}),
#              ('d',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.5,
#                           'e': 0.25,
#                           's': 0.25}),
#              ('d',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6666666666666666,
#                           'e': 0.3333333333333333}),
#              ('g',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1.0}),
#              ('a',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'f': 0.16666666666666666,
#                           'y': 0.16666666666666666,
#                           't': 0.16666666666666666,
#                           'r': 0.16666666666666666}),
#              ('l',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 1.0}),
#              ('u',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.75,
#                           'n': 0.25}),
#              ('d',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('t',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 1.0}),
#              ('y',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('q',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.3333333333333333,
#                           'a': 0.6666666666666666}),
#              ('c',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.3333333333333333,
#                           'w': 0.3333333333333333,
#                           's': 0.3333333333333333}),
#              ('k',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1.0}),
#              ('u',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('t',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('n',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('r',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('r',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.3333333333333333,
#                           'e': 0.6666666666666666}),
#              ('x',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.5,
#                           'd': 0.5}),
#              ('i',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.6666666666666666,
#                           't': 0.3333333333333333}),
#              ('y',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 1.0}),
#              ('h',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 1.0}),
#              ('x',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 1.0}),
#              ('k',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('c',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.3333333333333333,
#                           'n': 0.3333333333333333,
#                           's': 0.3333333333333333}),
#              ('m',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('z',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.5,
#                           's': 0.5}),
#              ('j',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1.0}),
#              ('z',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('m',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('e',
#               'w'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 1.0}),
#              ('r',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 1.0}),
#              ('d',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 1.0}),
#              ('d',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 1.0}),
#              ('h',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.5,
#                           'n': 0.5}),
#              ('u',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           's': 0.5}),
#              ('g',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('n',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5,
#                           's': 0.5}),
#              ('r',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('n',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('o',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 1.0}),
#              ('z',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 1.0}),
#              ('j',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('d',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 0.25,
#                           'e': 0.25,
#                           'i': 0.5}),
#              ('e',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('o',
#               'x'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('t',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 1.0}),
#              ('i',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 1.0}),
#              ('m',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('w',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 1.0}),
#              ('j',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 1.0})})

# %%
# Create an empty dictionary inside of a dictionary
it_model_3 = defaultdict(lambda: defaultdict(lambda: 0))

# loop through the words in the italian training list of words  
for words in train_it:
    
    # using the ngrams package loop through the trigrams and create a dictionary of counts for each trigram
    for let1, let2, let3 in ngrams(words, 3):
        it_model_3[(let1,let2)][let3] += 1


# transform the counts to probabilities
#loop through each key letter in the bigram model
for let1_let2 in it_model_3:
    
    # creates a total count of the values under the key letters
    total_count = float(sum(it_model_3[let1_let2].values()))
    
    # loops through the second letters of the bigrams for each first letter
    for let3 in it_model_3[let1_let2]:
        
        # divides the third letter count by the total count of the first two letter key in the trigram
        it_model_3[let1_let2][let3] /= total_count
        
        
it_model_3
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('c',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6363636363636364,
#                           'i': 0.3333333333333333,
#                           'é': 0.030303030303030304}),
#              ('d',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.4827586206896552,
#                           'r': 0.13793103448275862,
#                           'n': 0.05172413793103448,
#                           'a': 0.017241379310344827,
#                           'c': 0.034482758620689655,
#                           'v': 0.1206896551724138,
#                           't': 0.05172413793103448,
#                           'i': 0.05172413793103448,
#                           'e': 0.017241379310344827,
#                           'g': 0.017241379310344827,
#                           'f': 0.017241379310344827}),
#              ('e',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.8571428571428571,
#                           'e': 0.05714285714285714,
#                           'i': 0.05714285714285714,
#                           'a': 0.02857142857142857}),
#              ('l',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2727272727272727,
#                           'i': 0.045454545454545456,
#                           'a': 0.4772727272727273,
#                           'o': 0.1590909090909091,
#                           'u': 0.045454545454545456}),
#              ('c',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.125,
#                           'l': 0.0625,
#                           'c': 0.125,
#                           'i': 0.1875,
#                           'n': 0.25,
#                           'p': 0.0625,
#                           's': 0.125,
#                           'm': 0.0625}),
#              ('u',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.1,
#                           'b': 0.3,
#                           'a': 0.4,
#                           'e': 0.2}),
#              ('r',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.42857142857142855,
#                           'e': 0.2857142857142857,
#                           'a': 0.2857142857142857}),
#              ('r',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.15217391304347827,
#                           'm': 0.06521739130434782,
#                           'a': 0.13043478260869565,
#                           'o': 0.15217391304347827,
#                           't': 0.17391304347826086,
#                           'r': 0.10869565217391304,
#                           'b': 0.021739130434782608,
#                           's': 0.06521739130434782,
#                           'v': 0.043478260869565216,
#                           'e': 0.021739130434782608,
#                           'f': 0.021739130434782608,
#                           'd': 0.021739130434782608,
#                           'p': 0.021739130434782608}),
#              ('i',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.05405405405405406,
#                           'i': 0.32432432432432434,
#                           'o': 0.16216216216216217,
#                           'e': 0.10810810810810811,
#                           'a': 0.21621621621621623,
#                           'h': 0.02702702702702703,
#                           'c': 0.05405405405405406,
#                           'l': 0.02702702702702703,
#                           'r': 0.02702702702702703}),
#              ('u',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.16666666666666666,
#                           'l': 0.3333333333333333,
#                           'e': 0.16666666666666666,
#                           'a': 0.16666666666666666,
#                           't': 0.16666666666666666}),
#              ('l',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.2,
#                           't': 0.1,
#                           'o': 0.1,
#                           'c': 0.2,
#                           'n': 0.1,
#                           'p': 0.1,
#                           'b': 0.1,
#                           'l': 0.1}),
#              ('m',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.71875,
#                           't': 0.15625,
#                           'r': 0.09375,
#                           'g': 0.03125}),
#              ('e',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.5194805194805194,
#                           'e': 0.11688311688311688,
#                           'd': 0.18181818181818182,
#                           'a': 0.03896103896103896,
#                           's': 0.03896103896103896,
#                           'o': 0.03896103896103896,
#                           'z': 0.03896103896103896,
#                           'i': 0.012987012987012988,
#                           'n': 0.012987012987012988}),
#              ('n',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.10344827586206896,
#                           'i': 0.2413793103448276,
#                           'o': 0.13793103448275862,
#                           'e': 0.41379310344827586,
#                           'a': 0.10344827586206896}),
#              ('t',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.21875,
#                           'i': 0.28125,
#                           'a': 0.25,
#                           'o': 0.125,
#                           'u': 0.125}),
#              ('s',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.05555555555555555,
#                           'c': 0.2222222222222222,
#                           'a': 0.16666666666666666,
#                           'z': 0.05555555555555555,
#                           't': 0.1111111111111111,
#                           'o': 0.16666666666666666,
#                           'e': 0.05555555555555555,
#                           'v': 0.1111111111111111,
#                           'm': 0.05555555555555555}),
#              ('p',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.6086956521739131,
#                           't': 0.08695652173913043,
#                           'n': 0.15217391304347827,
#                           's': 0.021739130434782608,
#                           'l': 0.08695652173913043,
#                           'd': 0.021739130434782608,
#                           'g': 0.021739130434782608}),
#              ('e',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.07317073170731707,
#                           'e': 0.2926829268292683,
#                           't': 0.08536585365853659,
#                           'c': 0.0975609756097561,
#                           'a': 0.12195121951219512,
#                           'à': 0.024390243902439025,
#                           'f': 0.012195121951219513,
#                           'i': 0.12195121951219512,
#                           'g': 0.024390243902439025,
#                           'r': 0.024390243902439025,
#                           'b': 0.012195121951219513,
#                           'n': 0.024390243902439025,
#                           'v': 0.012195121951219513,
#                           'm': 0.024390243902439025,
#                           'd': 0.024390243902439025,
#                           'l': 0.012195121951219513,
#                           'o': 0.012195121951219513}),
#              ('r',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.8571428571428571,
#                           'i': 0.14285714285714285}),
#              ('s',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.4444444444444444,
#                           'l': 0.25925925925925924,
#                           'f': 0.07407407407407407,
#                           's': 0.1111111111111111,
#                           't': 0.037037037037037035,
#                           'g': 0.037037037037037035,
#                           'p': 0.037037037037037035}),
#              ('o',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.125,
#                           'i': 0.10714285714285714,
#                           'e': 0.2857142857142857,
#                           't': 0.08928571428571429,
#                           'd': 0.03571428571428571,
#                           'c': 0.03571428571428571,
#                           'n': 0.07142857142857142,
#                           'o': 0.17857142857142858,
#                           'f': 0.017857142857142856,
#                           's': 0.03571428571428571,
#                           'v': 0.017857142857142856}),
#              ('p',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.16666666666666666,
#                           'o': 0.2619047619047619,
#                           'e': 0.47619047619047616,
#                           'a': 0.09523809523809523}),
#              ('i',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.35714285714285715,
#                           'p': 0.2857142857142857,
#                           'm': 0.07142857142857142,
#                           'i': 0.07142857142857142,
#                           'e': 0.14285714285714285,
#                           'u': 0.07142857142857142}),
#              ('t',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.12903225806451613,
#                           'n': 0.12903225806451613,
#                           'p': 0.03225806451612903,
#                           'm': 0.12903225806451613,
#                           'c': 0.1935483870967742,
#                           'v': 0.25806451612903225,
#                           'l': 0.06451612903225806,
#                           't': 0.03225806451612903,
#                           'g': 0.03225806451612903}),
#              ('i',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.11764705882352941,
#                           'o': 0.058823529411764705,
#                           'e': 0.47058823529411764,
#                           'i': 0.11764705882352941,
#                           'c': 0.11764705882352941,
#                           's': 0.058823529411764705,
#                           't': 0.058823529411764705}),
#              ('r',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.047619047619047616,
#                           'i': 0.07142857142857142,
#                           'g': 0.11904761904761904,
#                           'd': 0.11904761904761904,
#                           't': 0.16666666666666666,
#                           'n': 0.19047619047619047,
#                           'l': 0.07142857142857142,
#                           'c': 0.047619047619047616,
#                           'z': 0.023809523809523808,
#                           'm': 0.047619047619047616,
#                           'f': 0.047619047619047616,
#                           's': 0.047619047619047616}),
#              ('a',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5211267605633803,
#                           'i': 0.09859154929577464,
#                           't': 0.14084507042253522,
#                           'r': 0.028169014084507043,
#                           'à': 0.014084507042253521,
#                           'l': 0.08450704225352113,
#                           'a': 0.056338028169014086,
#                           'b': 0.014084507042253521,
#                           'd': 0.028169014084507043,
#                           'm': 0.014084507042253521}),
#              ('m',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.125,
#                           'g': 0.25,
#                           'c': 0.375,
#                           'n': 0.25}),
#              ('i',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.09090909090909091,
#                           'r': 0.2727272727272727,
#                           'n': 0.45454545454545453,
#                           'd': 0.09090909090909091,
#                           't': 0.09090909090909091}),
#              ('a',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.11904761904761904,
#                           'm': 0.09523809523809523,
#                           'l': 0.2619047619047619,
#                           'u': 0.023809523809523808,
#                           'c': 0.16666666666666666,
#                           'e': 0.19047619047619047,
#                           'i': 0.14285714285714285}),
#              ('l',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.46153846153846156,
#                           'a': 0.15384615384615385,
#                           'e': 0.07692307692307693,
#                           'o': 0.15384615384615385,
#                           'i': 0.15384615384615385}),
#              ('a',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.25,
#                           'b': 0.21428571428571427,
#                           'e': 0.25,
#                           'p': 0.10714285714285714,
#                           'u': 0.03571428571428571,
#                           'm': 0.07142857142857142,
#                           'i': 0.07142857142857142}),
#              ('m',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2,
#                           'g': 0.1,
#                           'm': 0.05,
#                           'z': 0.05,
#                           'b': 0.1,
#                           'd': 0.2,
#                           't': 0.1,
#                           'l': 0.15,
#                           'n': 0.05}),
#              ('o',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.1320754716981132,
#                           'i': 0.18867924528301888,
#                           't': 0.2641509433962264,
#                           'n': 0.03773584905660377,
#                           'p': 0.05660377358490566,
#                           'm': 0.09433962264150944,
#                           'g': 0.03773584905660377,
#                           'r': 0.03773584905660377,
#                           'o': 0.03773584905660377,
#                           'd': 0.018867924528301886,
#                           'a': 0.07547169811320754,
#                           'z': 0.018867924528301886}),
#              ('f',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.15789473684210525,
#                           'c': 0.3157894736842105,
#                           'o': 0.10526315789473684,
#                           'n': 0.21052631578947367,
#                           'u': 0.05263157894736842,
#                           'g': 0.05263157894736842,
#                           'l': 0.10526315789473684}),
#              ('i',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.13333333333333333,
#                           't': 0.4666666666666667,
#                           's': 0.13333333333333333,
#                           'c': 0.06666666666666667,
#                           'p': 0.13333333333333333,
#                           'o': 0.06666666666666667}),
#              ('c',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.09090909090909091,
#                           'r': 0.18181818181818182,
#                           't': 0.18181818181818182,
#                           'm': 0.18181818181818182,
#                           'v': 0.13636363636363635,
#                           'l': 0.045454545454545456,
#                           's': 0.09090909090909091,
#                           'p': 0.045454545454545456,
#                           'f': 0.045454545454545456}),
#              ('a',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.07692307692307693,
#                           's': 0.03076923076923077,
#                           'g': 0.07692307692307693,
#                           'i': 0.06153846153846154,
#                           'd': 0.2153846153846154,
#                           't': 0.15384615384615385,
#                           'n': 0.13846153846153847,
#                           'z': 0.046153846153846156,
#                           'o': 0.13846153846153847,
#                           'e': 0.03076923076923077,
#                           'a': 0.03076923076923077}),
#              ('n',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2727272727272727,
#                           'h': 0.2727272727272727,
#                           'o': 0.36363636363636365,
#                           'i': 0.09090909090909091}),
#              ('c',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.1,
#                           'r': 0.25,
#                           't': 0.1,
#                           'n': 0.3,
#                           'g': 0.05,
#                           'v': 0.05,
#                           's': 0.15}),
#              ('l',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.13043478260869565,
#                           'o': 0.17391304347826086,
#                           'z': 0.08695652173913043,
#                           't': 0.13043478260869565,
#                           'n': 0.08695652173913043,
#                           'r': 0.043478260869565216,
#                           'f': 0.08695652173913043,
#                           'a': 0.043478260869565216,
#                           'c': 0.13043478260869565,
#                           'g': 0.043478260869565216,
#                           'b': 0.043478260869565216}),
#              ('i',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.5714285714285714,
#                           'n': 0.14285714285714285,
#                           'i': 0.14285714285714285,
#                           'o': 0.14285714285714285}),
#              ('g',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.9230769230769231,
#                           'e': 0.07692307692307693}),
#              ('i',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.3125,
#                           'n': 0.59375,
#                           'l': 0.0625,
#                           'v': 0.03125}),
#              ('i',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.10714285714285714,
#                           't': 0.21428571428571427,
#                           'c': 0.03571428571428571,
#                           'r': 0.17857142857142858,
#                           'n': 0.25,
#                           'l': 0.10714285714285714,
#                           'g': 0.07142857142857142,
#                           's': 0.03571428571428571}),
#              ('n',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.375,
#                           'a': 0.25,
#                           'u': 0.125,
#                           'e': 0.25}),
#              ('d',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'v': 0.38461538461538464,
#                           's': 0.15384615384615385,
#                           'g': 0.07692307692307693,
#                           'c': 0.07692307692307693,
#                           't': 0.15384615384615385,
#                           'n': 0.15384615384615385}),
#              ('o',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.4444444444444444,
#                           'e': 0.3333333333333333,
#                           'o': 0.1111111111111111,
#                           'a': 0.1111111111111111}),
#              ('v',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'e': 0.5}),
#              ('n',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.7142857142857143,
#                           's': 0.14285714285714285,
#                           't': 0.07142857142857142,
#                           'c': 0.07142857142857142}),
#              ('r',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.4375,
#                           'a': 0.28125,
#                           'o': 0.09375,
#                           'e': 0.125,
#                           'n': 0.03125,
#                           'u': 0.03125}),
#              ('i',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.10909090909090909,
#                           'd': 0.09090909090909091,
#                           'a': 0.21818181818181817,
#                           'g': 0.01818181818181818,
#                           'u': 0.03636363636363636,
#                           'i': 0.14545454545454545,
#                           'q': 0.05454545454545454,
#                           'v': 0.07272727272727272,
#                           't': 0.03636363636363636,
#                           's': 0.01818181818181818,
#                           'o': 0.07272727272727272,
#                           'c': 0.07272727272727272,
#                           'f': 0.03636363636363636,
#                           'n': 0.01818181818181818}),
#              ('n',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.05263157894736842,
#                           'l': 0.21052631578947367,
#                           't': 0.10526315789473684,
#                           'r': 0.2631578947368421,
#                           'g': 0.10526315789473684,
#                           's': 0.15789473684210525,
#                           'm': 0.05263157894736842,
#                           'a': 0.05263157894736842}),
#              ('p',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('c',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.18032786885245902,
#                           'n': 0.4098360655737705,
#                           'm': 0.11475409836065574,
#                           's': 0.11475409836065574,
#                           'r': 0.13114754098360656,
#                           'o': 0.01639344262295082,
#                           'p': 0.03278688524590164}),
#              ('o',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.25806451612903225,
#                           't': 0.22580645161290322,
#                           'p': 0.0967741935483871,
#                           'i': 0.12903225806451613,
#                           'l': 0.06451612903225806,
#                           'e': 0.12903225806451613,
#                           'a': 0.0967741935483871}),
#              ('l',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.3333333333333333,
#                           'r': 0.16666666666666666,
#                           's': 0.3333333333333333,
#                           'm': 0.16666666666666666}),
#              ('o',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.2,
#                           'l': 0.3,
#                           'h': 0.1,
#                           'r': 0.3,
#                           'n': 0.1}),
#              ('g',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.1,
#                           'o': 0.45,
#                           'a': 0.35,
#                           'n': 0.05,
#                           'l': 0.05}),
#              ('s',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.21428571428571427,
#                           'p': 0.2857142857142857,
#                           'o': 0.14285714285714285,
#                           'm': 0.07142857142857142,
#                           'e': 0.07142857142857142,
#                           'n': 0.07142857142857142,
#                           'f': 0.07142857142857142,
#                           'a': 0.07142857142857142}),
#              ('e',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.7586206896551724,
#                           'c': 0.034482758620689655,
#                           'e': 0.13793103448275862,
#                           'o': 0.034482758620689655,
#                           'a': 0.034482758620689655}),
#              ('t',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.1590909090909091,
#                           'o': 0.20454545454545456,
#                           'a': 0.18181818181818182,
#                           'i': 0.2727272727272727,
#                           'u': 0.13636363636363635,
#                           'à': 0.045454545454545456}),
#              ('t',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.4230769230769231,
#                           'n': 0.19230769230769232,
#                           'i': 0.038461538461538464,
#                           'g': 0.038461538461538464,
#                           's': 0.23076923076923078,
#                           'm': 0.07692307692307693}),
#              ('m',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.14814814814814814,
#                           'n': 0.3333333333333333,
#                           's': 0.14814814814814814,
#                           'v': 0.037037037037037035,
#                           'r': 0.07407407407407407,
#                           't': 0.07407407407407407,
#                           'z': 0.07407407407407407,
#                           'd': 0.037037037037037035,
#                           'c': 0.07407407407407407}),
#              ('a',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.06666666666666667,
#                           'a': 0.06666666666666667,
#                           'g': 0.6,
#                           'n': 0.06666666666666667,
#                           'i': 0.2}),
#              ('g',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2857142857142857,
#                           'a': 0.7142857142857143}),
#              ('u',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5714285714285714,
#                           't': 0.2857142857142857,
#                           'c': 0.14285714285714285}),
#              ('s',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.35294117647058826,
#                           'n': 0.11764705882352941,
#                           't': 0.11764705882352941,
#                           'l': 0.11764705882352941,
#                           'g': 0.11764705882352941,
#                           'p': 0.17647058823529413}),
#              ('b',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('u',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.6666666666666666,
#                           'e': 0.16666666666666666,
#                           'a': 0.16666666666666666}),
#              ('p',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.42857142857142855,
#                           'e': 0.14285714285714285,
#                           'i': 0.14285714285714285,
#                           'l': 0.14285714285714285,
#                           'a': 0.14285714285714285}),
#              ('p',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.42857142857142855,
#                           's': 0.32142857142857145,
#                           'l': 0.07142857142857142,
#                           'n': 0.03571428571428571,
#                           't': 0.14285714285714285}),
#              ('r',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'o': 0.2,
#                           'h': 0.2,
#                           'i': 0.1}),
#              ('n',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.22857142857142856,
#                           'e': 0.22857142857142856,
#                           'o': 0.4857142857142857,
#                           'u': 0.02857142857142857,
#                           'a': 0.02857142857142857}),
#              ('d',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'v': 0.0625,
#                           'n': 0.0625,
#                           'z': 0.125,
#                           'c': 0.0625,
#                           't': 0.125,
#                           's': 0.125,
#                           'a': 0.125,
#                           'r': 0.0625,
#                           'b': 0.0625,
#                           'p': 0.0625,
#                           'e': 0.0625,
#                           'f': 0.0625}),
#              ('i',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.21428571428571427,
#                           'o': 0.21428571428571427,
#                           'a': 0.5,
#                           'e': 0.07142857142857142}),
#              ('v',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.07692307692307693,
#                           'v': 0.07692307692307693,
#                           't': 0.3076923076923077,
#                           's': 0.23076923076923078,
#                           'a': 0.23076923076923078,
#                           'l': 0.07692307692307693}),
#              ('i',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.2857142857142857,
#                           'a': 0.14285714285714285,
#                           'e': 0.2857142857142857,
#                           'i': 0.14285714285714285,
#                           'r': 0.14285714285714285}),
#              ('d',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.1111111111111111,
#                           's': 0.1111111111111111,
#                           'r': 0.3333333333333333,
#                           'e': 0.2222222222222222,
#                           'n': 0.1111111111111111,
#                           'c': 0.1111111111111111}),
#              ('u',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.1,
#                           'n': 0.4,
#                           'l': 0.4,
#                           'z': 0.05,
#                           's': 0.05}),
#              ('s',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.30434782608695654,
#                           'o': 0.17391304347826086,
#                           'r': 0.21739130434782608,
#                           'u': 0.06521739130434782,
#                           'e': 0.10869565217391304,
#                           'i': 0.13043478260869565}),
#              ('a',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.75,
#                           'z': 0.25}),
#              ('z',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.045454545454545456,
#                           'a': 0.2727272727272727,
#                           'o': 0.6818181818181818}),
#              ('n',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.2857142857142857,
#                           'r': 0.14285714285714285,
#                           'i': 0.2857142857142857,
#                           'h': 0.14285714285714285,
#                           'l': 0.14285714285714285}),
#              ('g',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5,
#                           'a': 0.25,
#                           'e': 0.25}),
#              ('u',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.14285714285714285,
#                           'n': 0.42857142857142855,
#                           's': 0.14285714285714285,
#                           'd': 0.14285714285714285,
#                           'r': 0.14285714285714285}),
#              ('g',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.4,
#                           'o': 0.4,
#                           'a': 0.2}),
#              ('p',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ù': 0.36,
#                           'u': 0.08,
#                           'r': 0.12,
#                           'e': 0.16,
#                           'a': 0.08,
#                           'o': 0.08,
#                           'c': 0.08,
#                           's': 0.04}),
#              ('a',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.25,
#                           'a': 0.25,
#                           'r': 0.25,
#                           'o': 0.25}),
#              ('s',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.041666666666666664,
#                           'r': 0.375,
#                           'm': 0.125,
#                           'n': 0.25,
#                           't': 0.08333333333333333,
#                           'g': 0.041666666666666664,
#                           'd': 0.041666666666666664,
#                           's': 0.041666666666666664}),
#              ('o',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2,
#                           'p': 0.26666666666666666,
#                           'o': 0.2,
#                           'u': 0.06666666666666667,
#                           'a': 0.2,
#                           'b': 0.06666666666666667}),
#              ('u',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'f': 1.0}),
#              ('f',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.17647058823529413,
#                           'o': 0.17647058823529413,
#                           'e': 0.35294117647058826,
#                           'r': 0.11764705882352941,
#                           'a': 0.17647058823529413}),
#              ('c',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.125,
#                           't': 0.16666666666666666,
#                           'n': 0.25,
#                           'a': 0.16666666666666666,
#                           'd': 0.041666666666666664,
#                           'r': 0.08333333333333333,
#                           'ò': 0.041666666666666664,
#                           'e': 0.041666666666666664,
#                           'l': 0.041666666666666664,
#                           'c': 0.041666666666666664}),
#              ('n',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.09090909090909091,
#                           'z': 0.6363636363636364,
#                           't': 0.09090909090909091,
#                           'g': 0.09090909090909091,
#                           'a': 0.09090909090909091}),
#              ('i',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.8,
#                           'n': 0.2}),
#              ('u',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.5,
#                           'a': 0.09090909090909091,
#                           'o': 0.13636363636363635,
#                           'e': 0.09090909090909091,
#                           'r': 0.09090909090909091,
#                           'u': 0.045454545454545456,
#                           'i': 0.045454545454545456}),
#              ('t',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.25,
#                           'r': 0.375,
#                           'm': 0.1875,
#                           'p': 0.0625,
#                           'g': 0.0625,
#                           'l': 0.0625}),
#              ('o',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.34375,
#                           'i': 0.125,
#                           's': 0.21875,
#                           'c': 0.09375,
#                           'a': 0.09375,
#                           'e': 0.0625,
#                           'ì': 0.03125,
#                           'p': 0.03125}),
#              ('q',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.48148148148148145,
#                           'i': 0.18518518518518517,
#                           'e': 0.3333333333333333}),
#              ('a',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.2631578947368421,
#                           't': 0.10526315789473684,
#                           's': 0.3157894736842105,
#                           'a': 0.10526315789473684,
#                           'i': 0.15789473684210525,
#                           'p': 0.05263157894736842}),
#              ('s',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'h': 0.0625,
#                           'e': 0.1875,
#                           'i': 0.3125,
#                           'o': 0.1875,
#                           'a': 0.1875,
#                           'u': 0.0625}),
#              ('h',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 1.0}),
#              ('g',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'z': 0.14285714285714285,
#                           'n': 0.42857142857142855,
#                           'r': 0.14285714285714285,
#                           't': 0.14285714285714285,
#                           'l': 0.14285714285714285}),
#              ('z',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.25,
#                           'a': 0.625,
#                           'i': 0.125}),
#              ('i',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.75,
#                           'z': 0.25}),
#              ('a',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.23809523809523808,
#                           'r': 0.047619047619047616,
#                           't': 0.16666666666666666,
#                           'a': 0.19047619047619047,
#                           'o': 0.2619047619047619,
#                           'e': 0.09523809523809523}),
#              ('i',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.3333333333333333,
#                           'e': 0.3333333333333333,
#                           'r': 0.3333333333333333}),
#              ('e',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.1,
#                           'e': 0.3,
#                           'p': 0.5,
#                           'a': 0.1}),
#              ('o',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('a',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('b',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.125,
#                           'n': 0.1875,
#                           'c': 0.0625,
#                           'l': 0.375,
#                           'e': 0.0625,
#                           'o': 0.0625,
#                           'a': 0.0625,
#                           's': 0.0625}),
#              ('i',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.1111111111111111,
#                           'à': 0.18518518518518517,
#                           'a': 0.25925925925925924,
#                           'i': 0.1111111111111111,
#                           'o': 0.2222222222222222,
#                           't': 0.07407407407407407,
#                           'm': 0.037037037037037035}),
#              ('t',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.030303030303030304,
#                           'r': 0.15151515151515152,
#                           't': 0.24242424242424243,
#                           'a': 0.24242424242424243,
#                           'o': 0.21212121212121213,
#                           'e': 0.06060606060606061,
#                           'n': 0.06060606060606061}),
#              ('u',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('n',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.3888888888888889,
#                           't': 0.2222222222222222,
#                           's': 0.05555555555555555,
#                           'n': 0.1111111111111111,
#                           'm': 0.1111111111111111,
#                           'l': 0.1111111111111111}),
#              ('e',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.10256410256410256,
#                           'a': 0.05128205128205128,
#                           's': 0.41025641025641024,
#                           't': 0.358974358974359,
#                           'e': 0.05128205128205128,
#                           'i': 0.02564102564102564}),
#              ('s',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.2727272727272727,
#                           'i': 0.2727272727272727,
#                           'e': 0.2727272727272727,
#                           'a': 0.18181818181818182}),
#              ('u',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.4642857142857143,
#                           'i': 0.14285714285714285,
#                           'z': 0.07142857142857142,
#                           'e': 0.07142857142857142,
#                           'o': 0.07142857142857142,
#                           'q': 0.07142857142857142,
#                           'g': 0.03571428571428571,
#                           'n': 0.03571428571428571,
#                           't': 0.03571428571428571}),
#              ('r',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.24324324324324326,
#                           'd': 0.08108108108108109,
#                           'a': 0.10810810810810811,
#                           'v': 0.05405405405405406,
#                           'n': 0.24324324324324326,
#                           'b': 0.05405405405405406,
#                           'o': 0.02702702702702703,
#                           'g': 0.02702702702702703,
#                           't': 0.08108108108108109,
#                           'z': 0.02702702702702703,
#                           'p': 0.05405405405405406}),
#              ('s',
#               's'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.3225806451612903,
#                           'e': 0.2903225806451613,
#                           'i': 0.12903225806451613,
#                           'a': 0.1935483870967742,
#                           'u': 0.06451612903225806}),
#              ('a',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.25,
#                           'r': 0.25,
#                           'o': 0.125,
#                           'i': 0.25,
#                           'e': 0.125}),
#              ('r',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('b',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.4166666666666667,
#                           'm': 0.25,
#                           'c': 0.08333333333333333,
#                           't': 0.16666666666666666,
#                           'b': 0.08333333333333333}),
#              ('n',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.2,
#                           't': 0.6,
#                           'o': 0.2}),
#              ('a',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.4375,
#                           'v': 0.0625,
#                           'a': 0.125,
#                           'i': 0.0625,
#                           'o': 0.3125}),
#              ('v',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.7368421052631579,
#                           'd': 0.10526315789473684,
#                           's': 0.10526315789473684,
#                           't': 0.05263157894736842}),
#              ('t',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.3,
#                           'r': 0.3,
#                           't': 0.1,
#                           'p': 0.06666666666666667,
#                           'b': 0.03333333333333333,
#                           'c': 0.03333333333333333,
#                           'm': 0.03333333333333333,
#                           'i': 0.03333333333333333,
#                           'z': 0.03333333333333333,
#                           'v': 0.03333333333333333,
#                           'l': 0.03333333333333333}),
#              ('o',
#               't'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.16666666666666666,
#                           'e': 0.3333333333333333,
#                           'i': 0.3333333333333333,
#                           'a': 0.08333333333333333,
#                           'r': 0.08333333333333333}),
#              ('l',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('r',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('f',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.2,
#                           'r': 0.4,
#                           's': 0.1,
#                           'n': 0.2,
#                           'l': 0.1}),
#              ('r',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.5,
#                           'a': 0.5}),
#              ('g',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2222222222222222,
#                           'n': 0.6666666666666666,
#                           'l': 0.1111111111111111}),
#              ('g',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.9230769230769231,
#                           'a': 0.07692307692307693}),
#              ('f',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.4,
#                           'o': 0.4,
#                           'i': 0.2}),
#              ('e',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.125,
#                           'e': 0.25,
#                           'i': 0.625}),
#              ('d',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('v',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.3,
#                           'c': 0.1,
#                           'n': 0.2,
#                           'r': 0.3,
#                           'd': 0.1}),
#              ('l',
# ...
#                           'o': 0.125}),
#              ('f',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.3,
#                           'r': 0.6,
#                           'n': 0.1}),
#              ('o',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'c': 0.125,
#                           'u': 0.25,
#                           'e': 0.125}),
#              ('r',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.5,
#                           'o': 0.5}),
#              ('p',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'d': 0.05555555555555555,
#                           'c': 0.1111111111111111,
#                           't': 0.05555555555555555,
#                           'z': 0.05555555555555555,
#                           'r': 0.4444444444444444,
#                           's': 0.16666666666666666,
#                           'n': 0.05555555555555555,
#                           'e': 0.05555555555555555}),
#              ('d',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'a': 0.3333333333333333}),
#              ('e',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.3,
#                           'g': 0.4,
#                           'o': 0.1,
#                           'n': 0.2}),
#              ('m',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.7142857142857143,
#                           'r': 0.14285714285714285,
#                           'a': 0.14285714285714285}),
#              ('c',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.8,
#                           'o': 0.2}),
#              ('e',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.2857142857142857,
#                           'n': 0.14285714285714285,
#                           'l': 0.14285714285714285,
#                           'm': 0.2857142857142857,
#                           'd': 0.14285714285714285}),
#              ('h',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.8,
#                           'n': 0.2}),
#              ('e',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6666666666666666,
#                           'e': 0.13333333333333333,
#                           'a': 0.06666666666666667,
#                           'o': 0.13333333333333333}),
#              ('l',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.25,
#                           'a': 0.16666666666666666,
#                           'v': 0.08333333333333333,
#                           'z': 0.16666666666666666,
#                           'g': 0.08333333333333333,
#                           'i': 0.08333333333333333,
#                           'm': 0.16666666666666666}),
#              ('r',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'p': 0.2222222222222222,
#                           'v': 0.1111111111111111,
#                           't': 0.05555555555555555,
#                           'n': 0.1111111111111111,
#                           'm': 0.1111111111111111,
#                           'g': 0.1111111111111111,
#                           'b': 0.05555555555555555,
#                           'f': 0.05555555555555555,
#                           's': 0.1111111111111111,
#                           'c': 0.05555555555555555}),
#              ('o',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.4444444444444444,
#                           'o': 0.1111111111111111,
#                           'e': 0.1111111111111111,
#                           'p': 0.1111111111111111,
#                           'i': 0.1111111111111111,
#                           'l': 0.1111111111111111}),
#              ('n',
#               'q'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0}),
#              ('u',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6,
#                           'e': 0.4}),
#              ('a',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'f': 0.8333333333333334,
#                           'i': 0.16666666666666666}),
#              ('v',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('m',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 0.3125,
#                           'r': 0.25,
#                           'o': 0.25,
#                           'e': 0.125,
#                           'i': 0.0625}),
#              ('p',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2857142857142857,
#                           'i': 0.5714285714285714,
#                           'a': 0.14285714285714285}),
#              ('n',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.625,
#                           'e': 0.3125,
#                           'a': 0.0625}),
#              ('a',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 0.6470588235294118,
#                           'q': 0.11764705882352941,
#                           'e': 0.058823529411764705,
#                           'u': 0.058823529411764705,
#                           'i': 0.058823529411764705,
#                           'o': 0.058823529411764705}),
#              ('c',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.3333333333333333,
#                           'h': 0.26666666666666666,
#                           'u': 0.06666666666666667,
#                           'i': 0.2,
#                           'o': 0.13333333333333333}),
#              ('n',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.25,
#                           'i': 0.625,
#                           'a': 0.125}),
#              ('l',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.2,
#                           'r': 0.3,
#                           'v': 0.3,
#                           'b': 0.1,
#                           'n': 0.1}),
#              ('v',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.2,
#                           'm': 0.2,
#                           'r': 0.2,
#                           'i': 0.1,
#                           'n': 0.2,
#                           's': 0.1}),
#              ('c',
#               'q'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0}),
#              ('r',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('d',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.08333333333333333,
#                           't': 0.25,
#                           'l': 0.3333333333333333,
#                           'n': 0.25,
#                           'i': 0.08333333333333333}),
#              ('m',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('r',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.375,
#                           'a': 0.5,
#                           'o': 0.125}),
#              ('n',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.8,
#                           'i': 0.2}),
#              ('f',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'g': 0.07142857142857142,
#                           'r': 0.35714285714285715,
#                           'c': 0.14285714285714285,
#                           's': 0.21428571428571427,
#                           'i': 0.07142857142857142,
#                           'l': 0.14285714285714285}),
#              ('m',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.25,
#                           'n': 0.25,
#                           'l': 0.5}),
#              ('h',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'m': 0.125,
#                           'c': 0.125,
#                           'u': 0.125,
#                           'n': 0.25,
#                           'a': 0.375}),
#              ('i',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.2857142857142857,
#                           'i': 0.2857142857142857,
#                           'm': 0.21428571428571427,
#                           'u': 0.07142857142857142,
#                           'a': 0.07142857142857142,
#                           'l': 0.07142857142857142}),
#              ('e',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'z': 1.0}),
#              ('l',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.5714285714285714,
#                           'o': 0.2857142857142857,
#                           'h': 0.14285714285714285}),
#              ('p',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ò': 0.4,
#                           'o': 0.4,
#                           'n': 0.2}),
#              ('u',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5,
#                           'g': 0.1,
#                           'v': 0.1,
#                           'm': 0.1,
#                           'l': 0.1,
#                           'n': 0.1}),
#              ('e',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'b': 1.0}),
#              ('b',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 0.6666666666666666,
#                           'l': 0.3333333333333333}),
#              ('e',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'c': 1.0}),
#              ('a',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 1.0}),
#              ('o',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.5,
#                           'a': 0.25,
#                           'b': 0.25}),
#              ('e',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('r',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'t': 0.5,
#                           'z': 0.5}),
#              ('b',
#               'r'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 0.6666666666666666,
#                           'o': 0.3333333333333333}),
#              ('o',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.6,
#                           'e': 0.2,
#                           'k': 0.2}),
#              ('r',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.2857142857142857,
#                           'e': 0.14285714285714285,
#                           'i': 0.14285714285714285,
#                           'a': 0.42857142857142855}),
#              ('u',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.2857142857142857,
#                           'l': 0.7142857142857143}),
#              ('u',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('e',
#               'c'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.6666666666666666,
#                           'c': 0.3333333333333333}),
#              ('f',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('i',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.3333333333333333,
#                           'i': 0.3333333333333333,
#                           'r': 0.3333333333333333}),
#              ('b',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 0.5,
#                           'o': 0.5}),
#              ('g',
#               'h'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('n',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 0.3333333333333333,
#                           'o': 0.6666666666666666}),
#              ('z',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'r': 1.0}),
#              ('g',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 1.0}),
#              ('a',
#               'i'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0}),
#              ('u',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 0.25,
#                           'e': 0.25,
#                           'a': 0.25,
#                           'i': 0.25}),
#              ('i',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 0.75,
#                           'f': 0.25}),
#              ('s',
#               'b'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('o',
#               'o'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 1.0}),
#              ('r',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('t',
#               'n'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('t',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('a',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'s': 0.5,
#                           'r': 0.5}),
#              ('s',
#               'g'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('r',
#               'd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.2,
#                           'a': 0.4,
#                           'i': 0.2,
#                           'e': 0.2}),
#              ('s',
#               'v'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('c',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.5,
#                           'a': 0.5}),
#              ('v',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'o': 1.0}),
#              ('e',
#               'f'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 0.5,
#                           'f': 0.5}),
#              ('e',
#               'p'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('r',
#               'z'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('z',
#               'e'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'n': 1.0}),
#              ('s',
#               'm'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'e': 1.0}),
#              ('b',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'i': 1.0}),
#              ('d',
#               'k'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 1.0}),
#              ('1',
#               '2'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'5': 1.0}),
#              ('s',
#               'q'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1.0})})

# %%
# predictor function that uses trigram model to predict the language of the words in the English test list of words
def trigram_language_predictor(en_model,it_model, test_listofwords):
    
    # create empty results list to be appended to
    results = []
    
    # loop that goes through all of the words in the test list of words    
    for word in test_listofwords:
        
        # initially setting the probability of the word being engluish and italian to 1    
        en_prob = 1
        it_prob =1
        
        # looping through the trigrams in each word
        for let1, let2, let3 in ngrams(word, 3):
            
            # if else clause incase the two first letters is not a key in the dictionary from the english training list of words
            if (let1, let2) not in en_model.keys():
                en_prob = en_prob
            else: 
                # model creates a probability of if the test word is english by multiplying the trigram frequncies together
                en_prob = en_prob * en_model[(let1,let2)][let3]
                    
                
            # if else clause incase the two first letters is not a key in the dictionary from the english training list of words    
            if (let1,let2) not in it_model.keys():
                it_prob = it_prob
            else:
                # model creates a probability of if the test word is english by multiplying the trigram frequncies together
                it_prob = it_prob * it_model[(let1,let2)][let3]
        
        # if else statement to flag which language has a higher probability and assign that language to a variable
        if en_prob >= it_prob:
            en_flag = 1
            pred_lang= 'English'
        else:
            en_flag = 0
            pred_lang = 'Italian'
        
        # append the results to a results list created at the start of the function
        results.append([word,en_prob, it_prob, en_flag, pred_lang])
            
    return results

# %%
# run predictor using the english and italian trigram frequency dictionaries and the english test list of words
trigram_res = trigram_language_predictor(en_model_3,it_model_3, test_en)

trigram_res
# Out:
# [['a', 1, 1, 1, 'English'],
#  ['for', 0.6666666666666666, 0.6, 1, 'English'],
#  ['of', 1, 1, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['a', 1, 1, 1, 'English'],
#  ['street', 4.3841189674523005e-05, 0.0, 1, 'English'],
#  ['easier', 0.0, 0.0, 1, 'English'],
#  ['help', 0.036, 0, 1, 'English'],
#  ['physical', 0.0, 0.002184002184002184, 0, 'Italian'],
#  ['thoughts', 0.0, 0, 1, 'English'],
#  ['is', 1, 1, 1, 'English'],
#  ['on', 1, 1, 1, 'English'],
#  ['areas', 0.00916138125440451, 0.0, 1, 'English'],
#  ['for', 0.6666666666666666, 0.6, 1, 'English'],
#  ['down', 0.0, 0, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['websites', 0.0, 0.0, 1, 'English'],
#  ['pizzas', 0.013888888888888888, 0.0, 1, 'English'],
#  ['other', 0.1157938144329897, 0.0, 1, 'English'],
#  ['travels', 0.0, 0.0, 1, 'English'],
#  ['ones', 0.04081632653061224, 0.045112781954887216, 0, 'Italian'],
#  ['to', 1, 1, 1, 'English'],
#  ['this', 0.002689376961004034, 0, 1, 'English'],
#  ['interest', 0.0003536003536003536, 0.00016269398426349967, 1, 'English'],
#  ['get', 0.16666666666666666, 0, 1, 'English'],
#  ['together', 0.0, 0.0, 1, 'English'],
#  ['company', 0.0005120327700972862, 0.0, 1, 'English'],
#  ['firm', 0, 0, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['feel', 0.06818181818181818, 0, 1, 'English'],
#  ['part', 0.06330749354005169, 0.06259780907668232, 1, 'English'],
#  ['not', 0.3333333333333333, 0.07142857142857142, 1, 'English'],
#  ['opening', 0.00023253243502382114, 0.0, 1, 'English'],
#  ['affairs', 0.0, 0.0, 1, 'English'],
#  ['more', 0.11278195488721804, 0.026415094339622643, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['bring', 0.02902979373567609, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['cool', 0.0, 0.01639344262295082, 0, 'Italian'],
#  ['most', 0.047619047619047616, 0.0, 1, 'English'],
#  ['score', 0.023391812865497075, 0.0032477575007732757, 1, 'English'],
#  ['oatmeal', 0.0, 0.0, 1, 'English'],
#  ['consider', 1.4682554365094048e-05, 0.0, 1, 'English'],
#  ['of', 1, 1, 1, 'English'],
#  ['take', 0.11483253588516747, 0, 1, 'English'],
#  ['insult', 0.0, 8.116883116883116e-05, 0, 'Italian'],
#  ['dinner', 0.0002944900904084577, 9.345095693779904e-05, 1, 'English'],
#  ['body', 0.08035714285714285, 0, 1, 'English'],
#  ['for', 0.6666666666666666, 0.6, 1, 'English'],
#  ['adults', 0, 0.0, 1, 'English'],
#  ['strong', 0.00036743092298647845, 0.0, 1, 'English'],
#  ['and', 0.5483870967741935, 0.2153846153846154, 1, 'English'],
#  ['years', 0.0, 0.0, 1, 'English'],
#  ['fertilizer', 0.0, 0.0, 1, 'English'],
#  ['out', 0.11864406779661017, 1, 0, 'Italian'],
#  ['dog', 0, 0.07692307692307693, 0, 'Italian'],
#  ['this', 0.002689376961004034, 0, 1, 'English'],
#  ['decide', 0.009448223733938018, 0.00027367268746579087, 1, 'English'],
#  ['not', 0.3333333333333333, 0.07142857142857142, 1, 'English'],
#  ['interest', 0.0003536003536003536, 0.00016269398426349967, 1, 'English'],
#  ['meals', 0.00035932446999640676, 0.0, 1, 'English'],
#  ['about', 0.019774011299435026, 0, 1, 'English'],
#  ['can', 0.36666666666666664, 0.09090909090909091, 1, 'English'],
#  ['take', 0.11483253588516747, 0, 1, 'English'],
#  ['wrist', 0.0213903743315508, 0.030434782608695653, 0, 'Italian'],
#  ['worth', 0.01804511278195488, 0.0, 1, 'English'],
#  ['part', 0.06330749354005169, 0.06259780907668232, 1, 'English'],
#  ['got', 0, 0, 1, 'English'],
#  ['trauma', 0.0, 0.0, 1, 'English'],
#  ['dough', 0.010169491525423728, 0, 1, 'English'],
#  ['insurance', 0.0, 0.0, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['credit', 0.0, 0.005067567567567568, 0, 'Italian'],
#  ['time', 0.04301075268817204, 0.018433179723502304, 1, 'English'],
#  ['can', 0.36666666666666664, 0.09090909090909091, 1, 'English'],
#  ['club', 0, 0.05, 0, 'Italian'],
#  ['leave', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['and', 0.5483870967741935, 0.2153846153846154, 1, 'English'],
#  ['just', 0.4, 0.2857142857142857, 1, 'English'],
#  ['stories', 0.0, 0.0, 1, 'English'],
#  ['that', 0.019681349578256797, 0, 1, 'English'],
#  ['around', 4.777773796299614e-05, 0, 1, 'English'],
#  ['or', 1, 1, 1, 'English'],
#  ['art', 0.16279069767441862, 0.14084507042253522, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['comes', 0.05314009661835749, 0.0, 1, 'English'],
#  ['are', 0.3023255813953488, 0.5211267605633803, 0, 'Italian'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['help', 0.036, 0, 1, 'English'],
#  ['level', 0.0, 0.0, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['back', 0, 0.0, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['growth', 0.007407407407407408, 0, 1, 'English'],
#  ['work', 0.0631578947368421, 0, 1, 'English'],
#  ['hitting', 0.0, 0.0, 1, 'English'],
#  ['life', 0.18181818181818182, 0.0, 1, 'English'],
#  ['kiss', 0.0, 0.13333333333333333, 0, 'Italian'],
#  ['health', 0.0004958677685950413, 0.0, 1, 'English'],
#  ['golf', 0.0, 0.0, 1, 'English'],
#  ['shares', 0.0006543843753146079, 0.0, 1, 'English'],
#  ['hide', 0.036231884057971016, 0.0, 1, 'English'],
#  ['of', 1, 1, 1, 'English'],
#  ['ball', 0.12987012987012986, 0.0, 1, 'English'],
#  ['shoes', 0.0, 1, 0, 'Italian'],
#  ['throat', 0.0, 0, 1, 'English'],
#  ['irritation', 4.499240872073147e-06, 0.0, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['their', 0.06701030927835053, 0, 1, 'English'],
#  ['films', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['ve', 1, 1, 1, 'English'],
#  ['look', 0.03676470588235294, 0, 1, 'English'],
#  ['sound', 0.0009731570837726057, 0, 1, 'English'],
#  ['good', 0.08823529411764706, 0, 1, 'English'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['or', 1, 1, 1, 'English'],
#  ['and', 0.5483870967741935, 0.2153846153846154, 1, 'English'],
#  ['for', 0.6666666666666666, 0.6, 1, 'English'],
#  ['benefit', 0.0, 0.0, 1, 'English'],
#  ['rent', 0.06439393939393939, 0.12636012636012636, 0, 'Italian'],
#  ['watch', 0.017094017094017096, 0, 1, 'English'],
#  ['any', 0.14516129032258066, 0, 1, 'English'],
#  ['each', 0.014545454545454545, 0, 1, 'English'],
#  ['here', 0.054857142857142854, 0.2926829268292683, 0, 'Italian'],
#  ['overall', 0.00036647655695274734, 0.0005603439493041546, 0, 'Italian'],
#  ['data', 0, 0.047619047619047616, 0, 'Italian'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['a', 1, 1, 1, 'English'],
#  ['designs', 0.0, 0.0, 1, 'English'],
#  ['into', 0.0, 0.005015673981191222, 0, 'Italian'],
#  ['protect', 0.0, 0.0, 1, 'English'],
#  ['enemies', 0.0, 0.0, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['as', 1, 1, 1, 'English'],
#  ['include', 0.0, 0.0, 1, 'English'],
#  ['possibilities', 0.0, 0.0, 1, 'English'],
#  ['having', 0.0019033308289506637, 0.0, 1, 'English'],
#  ['leave', 0.0, 0.0, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['support', 0.0, 0.009241432422025412, 0, 'Italian'],
#  ['emotions', 0.0, 0.0, 1, 'English'],
#  ['of', 1, 1, 1, 'English'],
#  ['embroidery', 0.0, 0.0, 1, 'English'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['dozens', 0.0, 0.0, 1, 'English'],
#  ['half', 0.0013774104683195593, 0, 1, 'English'],
#  ['doctor', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['as', 1, 1, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['from', 0.013888888888888888, 0.044444444444444446, 0, 'Italian'],
#  ['physically', 0.0, 0.0, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['find', 0.01062573789846517, 0.019138755980861243, 0, 'Italian'],
#  ['adventure', 0.00016986899702949084, 0.0, 1, 'English'],
#  ['that', 0.019681349578256797, 0, 1, 'English'],
#  ['will', 0.21, 0.07142857142857142, 1, 'English'],
#  ['dress', 0.019886363636363636, 0.06652806652806653, 0, 'Italian'],
#  ['contact', 1.3201728601338736e-05, 0.0, 1, 'English'],
#  ['loan', 0.1875, 0, 1, 'English'],
#  ['crisis', 0.0, 0.0, 1, 'English'],
#  ['want', 0.02977667493796526, 0.15384615384615385, 0, 'Italian'],
#  ['some', 0.14473684210526316, 0.0, 1, 'English'],
#  ['learn', 0.0015578057193724269, 0.0, 1, 'English'],
#  ['simply', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['connect', 0.0, 0.0, 1, 'English'],
#  ['relaxing', 0.0, 0.0, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['any', 0.14516129032258066, 0, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['disturb', 0.0006660006660006659, 0.00017292490118577076, 1, 'English'],
#  ['s', 1, 1, 1, 'English'],
#  ['anyone', 0.0, 0.0, 1, 'English'],
#  ['rate', 0.1111111111111111, 0.015873015873015872, 1, 'English'],
#  ['if', 1, 1, 1, 'English'],
#  ['with', 0.16842105263157894, 0, 1, 'English'],
#  ['smaller', 0.000828517574929058, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['vodka', 0, 0.020000000000000004, 0, 'Italian'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['making', 0.009613762860516106, 0.0, 1, 'English'],
#  ['person', 0.007365352155899952, 0.016967126193001062, 0, 'Italian'],
#  ['of', 1, 1, 1, 'English'],
#  ['or', 1, 1, 1, 'English'],
#  ['variety', 0.0, 0.0, 1, 'English'],
#  ['browns', 0.008888888888888889, 0.0, 1, 'English'],
#  ['brain', 0.0, 0.0, 1, 'English'],
#  ['of', 1, 1, 1, 'English'],
#  ['how', 0.1, 1, 0, 'Italian'],
#  ['are', 0.3023255813953488, 0.5211267605633803, 0, 'Italian'],
#  ['you', 1.0, 1, 1, 'English'],
#  ['or', 1, 1, 1, 'English'],
#  ['quality', 0.00043497172683775554, 0.0, 1, 'English'],
#  ['as', 1, 1, 1, 'English'],
#  ['listening', 8.90759718708629e-06, 0.0, 1, 'English'],
#  ['can', 0.36666666666666664, 0.09090909090909091, 1, 'English'],
#  ['be', 1, 1, 1, 'English'],
#  ['insurance', 0.0, 0.0, 1, 'English'],
#  ['snacks', 0.0, 0, 1, 'English'],
#  ['an', 1, 1, 1, 'English'],
#  ['colors', 0.0, 0.0, 1, 'English'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['enjoy', 0, 0, 1, 'English'],
#  ['will', 0.21, 0.07142857142857142, 1, 'English'],
#  ['can', 0.36666666666666664, 0.09090909090909091, 1, 'English'],
#  ['irritate', 7.510271301845176e-05, 0.0, 1, 'English'],
#  ['there', 0.044111929307805595, 0.2926829268292683, 0, 'Italian'],
#  ['floor', 0.0007352941176470588, 0, 1, 'English'],
#  ['for', 0.6666666666666666, 0.6, 1, 'English'],
#  ['and', 0.5483870967741935, 0.2153846153846154, 1, 'English'],
#  ['from', 0.013888888888888888, 0.044444444444444446, 0, 'Italian'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['from', 0.013888888888888888, 0.044444444444444446, 0, 'Italian'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['away', 0.13846153846153847, 1, 0, 'Italian'],
#  ['by', 1, 1, 1, 'English'],
#  ['crisis', 0.0, 0.0, 1, 'English'],
#  ['your', 0.5084745762711864, 1, 0, 'Italian'],
#  ['inspire', 1.8219715189412155e-05, 0.0, 1, 'English'],
#  ['before', 0.008771929824561403, 0.0, 1, 'English'],
#  ['felt', 0.0, 0.0, 1, 'English'],
#  ['children', 0.00034838350055741357, 0.0, 1, 'English'],
#  ['leads', 0.0, 0.0, 1, 'English'],
#  ['milestones', 2.225566135340571e-07, 0.0, 1, 'English'],
#  ['them', 0.04824742268041237, 0, 1, 'English'],
#  ['plastic', 1.0971011296850332e-05, 0.0, 1, 'English'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['party', 0.0, 0.0, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['the', 0.8041237113402062, 1, 0, 'Italian'],
#  ['top', 0, 0.0625, 0, 'Italian'],
#  ['television', 0.0, 0.0, 1, 'English'],
#  ['happiness', 0.00020869855580599384, 0.0, 1, 'English'],
#  ['so', 1, 1, 1, 'English'],
#  ['sewing', 0.0, 0.0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['with', 0.16842105263157894, 0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['meditation', 0.0, 0.0, 1, 'English'],
#  ['thin', 0.010757507844016136, 0.25, 0, 'Italian'],
#  ['love', 0.08333333333333333, 0.0, 1, 'English'],
#  ['whose', 0.003333333333333334, 0.0625, 0, 'Italian'],
#  ['cars', 0.0, 0.0, 1, 'English'],
#  ['to', 1, 1, 1, 'English'],
#  ['friendship', 1.1071622324819254e-05, 0.0, 1, 'English'],
#  ['doors', 0.0010319917440660474, 0, 1, 'English'],
#  ['a', 1, 1, 1, 'English'],
#  ['do', 1, 1, 1, 'English'],
#  ['vary', 0.004651162790697674, 0.0, 1, 'English'],
#  ['negotiations', 0.0, 0.0, 1, 'English'],
#  ['or', 1, 1, 1, 'English'],
#  ['cross', 0.006172839506172839, 0.004861111111111111, 1, 'English'],
#  ['blind', 0.0014167650531286898, 0.007905138339920948, 0, 'Italian']]

# %%
# create a dataframe from the resulting list
df_trigram_res = pd.DataFrame(trigram_res,columns = ['word','en_prob','it_prob','english','language prediction'])

df_trigram_res.head(20)
# Out:
#         word   en_prob   it_prob  english language prediction
# 0          a  1.000000  1.000000        1             English
# 1        for  0.666667  0.600000        1             English
# 2         of  1.000000  1.000000        1             English
# 3       your  0.508475  1.000000        0             Italian
# 4          a  1.000000  1.000000        1             English
# 5     street  0.000044  0.000000        1             English
# 6     easier  0.000000  0.000000        1             English
# 7       help  0.036000  0.000000        1             English
# 8   physical  0.000000  0.002184        0             Italian
# 9   thoughts  0.000000  0.000000        1             English
# 10        is  1.000000  1.000000        1             English
# 11        on  1.000000  1.000000        1             English
# 12     areas  0.009161  0.000000        1             English
# 13       for  0.666667  0.600000        1             English
# 14      down  0.000000  0.000000        1             English
# 15        to  1.000000  1.000000        1             English
# 16  websites  0.000000  0.000000        1             English
# 17    pizzas  0.013889  0.000000        1             English
# 18     other  0.115794  0.000000        1             English
# 19   travels  0.000000  0.000000        1             English

# %%
# count the number of words classified as an english word
eng_pos = df_trigram_res.english.sum()

# count the number of words in the df
total_words = len(df_trigram_res.index)

# calculate the accuracy of the trigram model
accuracy_trigram = eng_pos/total_words

accuracy_trigram
# Out:
# 0.8060836501901141
